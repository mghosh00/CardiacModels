# %% [markdown]
# # Inferring parameters for the Beeler-Reuter Model

# %% [markdown]
# In this notebook, we use PINTS to create noisy data for a Beeler-Reuter system and then perform inference on the model
# to try and retrieve the parameters. This should be compared with results from other notebooks, such as the FitzHugh-Nagumo
# notebook.

# %% [markdown]
# ## Creating the ForwardModel

# %% [markdown]
# ### Variable descriptions

# %% [markdown]
# Firstly, we set up the system of ODEs for the Beeler-Reuter system. Below is a description of the 8 time-dependent variables
# present in the model (which form a system of 8 ODEs), and we follow the notation of Keener and Sneyd (1998) Section 4.3 [$^{[1]}$](#Sources).

# %% [markdown]
# |variable|description|ion|
# |---|-------|---|
# |$V$|membrane potential|all|
# |$m$|fast sodium activation gating variable|$Na^{+}$|
# |$h$|fast sodium inactivation gating variable|$Na^{+}$|
# |$j$|fast sodium reactivation gating variable|$Na^{+}$|
# |$d$|slow inward calcium activation gating variable|$Ca^{2+}$|
# |$f$|slow inward calcium inactivation gating variable|$Ca^{2+}$|
# |$c$|$10^{7}[Ca]_{i}$ where $[Ca]_{i}$ is the internal calcium concentration|$Ca^{2+}$|
# |$x$|outward potassium gating variable|$K^{+}$|

# %% [markdown]
# ### Membrane potential ODE

# %% [markdown]
# For the ODEs, we follow some of the notation from the original Beeler and Reuter paper from 1977 [$^{[2]}$](#Sources).
# The governing ODE for the membrane potential is:

# %% [markdown]
# \begin{equation}
#     C_{m}\frac{dV}{dt} = - (I_{Na} + I_{K} + I_{x} + I_{Ca}) + I_{stim},
# \end{equation}
# where
# \begin{equation}
#     I_{Na} = (g_{Na}m^{3}hj + g_{NaC})(V - V_{Na}),
# \end{equation}
# \begin{equation}
#     I_{K} = g_{K_1}\frac{\exp{(0.04(V - V_{K_1}))} - 1}{\exp{(0.08(V - V_{K_2}))} + \exp{(0.04(V - V_{K_2}))}} +
#             g_{K_2}\frac{V - V_{K_3}}{1 - \exp{(- 0.04(V - V_{K_3}))}},
# \end{equation}
# \begin{equation}
#     I_{x} = g_{x}x\frac{\exp{(0.04(V - V_{x_1}))} - 1}{\exp{(0.04(V - V_{x_2}))}},
# \end{equation}
# \begin{equation}
#     I_{Ca} = g_{Ca}fd(V - V_{Ca} + 13.0287\ln{(10^{-7}c))}.
# \end{equation}

# %% [markdown]
# During inference, the model will have the capability to infer any of the conductances, $g_{i}$ for any subscript $i$, and any of the
# Nernst (or other) potential constants, $V_{i}$. Therefore we have up to 13 parameters (6 conductances and 7 potentials) to infer. Note that
# we also fix $C_{m}$ = 1.

# %% [markdown]
# For the stimulating current, $I_{stim}$, we will allow flexibility for specifying the following parameters:

# %% [markdown]
# |parameter|description|
# |---|--------|
# |`stim_start`|The time at which the current is turned on.|
# |`stim_period`|The length of a stimulation cycle.|
# |`stim_duration`|The period for which (at the start of the stimulation cycle) the current is turned on.|
# |`stim_amplitude`|The amplitude of the current.|

# %% [markdown]
# These will be captured in a 4-membered list, and passed to the `BeelerReuterModel` below. None of these parameters will be inferred.

# %% [markdown]
# ### Gating variable and $Ca^{2+}$ ODEs

# %% [markdown]
# Below are the remaining 7 ODEs:

# %% [markdown]
# \begin{equation}
#     \frac{dy}{dt} = \alpha_{y}(1 - y) - \beta_{y}y,
# \end{equation}
# \begin{equation}
#     \frac{dc}{dt} = 0.07(1 - c) - I_{Ca},
# \end{equation}

# %% [markdown]
# where $y = m, h, j, d, f, x$ and $\alpha_{y}, \beta_{y}$ are some known functions of the membrane potential, $V$ (so we will
# not be inferring any parameters contained within these functions).

# %% [markdown]
# ### Initial conditions

# %% [markdown]
# Finally, we will assume the following initial conditions are known (using values from CellML [$^{[3]}$](#Sources)):

# %% [markdown]
# \begin{equation}
#     V(0) = -84.624, \qquad m(0) = 0.011, \qquad h(0) = 0.988, \qquad j(0) = 0.975, \qquad d(0) = 0.003, \qquad f(0) = 0.994,
#     \qquad x(0) = 0.0001, \qquad c(0) = 2.
# \end{equation}

# %% [markdown]
# The goal is to try and initially infer all 13 parameters, and then see which parameters we can restrict to improve the overall inference.

# %%
initial_conditions = [-84.624, 0.011, 0.988, 0.975, 0.003, 0.994, 0.0001, 2]

# %%
from numpy import exp, log

import pints
import numpy as np
import scipy.integrate as si
import matplotlib.pyplot as plt

# %% [markdown]
# ### PINTS implementation of the model

# %% [markdown]
# In addition to implementing the system, we give the option in the class to specify fixed parameters, if we wish to
# reduce the dimensions of the parameter space. Additionally, as we realistically would only be able to measure the membrane potential,
# $V$, and the calcium concentration, $c$, we will use these as the only outputs of the system.

# %%
class BeelerReuterModel(pints.ForwardModel):

    def __init__(self, initial_conditions, stimulating_current, fixed_params=None, outputs=["V", "c"]):
        """Initialises the forward model with certain fixed parameters passed to the method
        as key-value pairs.
        """
        super(BeelerReuterModel, self).__init__()
        assert len(initial_conditions) == 8
        self._initial_conditions = initial_conditions

        assert len(stimulating_current) == 4
        self._stim_start, self._stim_period, self._stim_duration, self._stim_amplitude = tuple(stimulating_current)
        self._param_names = ["g_Na", "g_NaC", "g_K1", "g_K2", "g_x", "g_Ca",
                             "V_Na", "V_K1", "V_K2", "V_K3", "V_x1", "V_x2", "V_Ca"]
        self._variable_names = ["V", "m", "h", "j", "d", "f", "x", "c"]
        self._fixed_params = {}
        if fixed_params is not None:
            for k in fixed_params.keys():
                if k in self._param_names:
                    self._fixed_params[k] = fixed_params[k]

        assert 1 <= len(outputs) <= 8
        assert set(outputs).issubset(set(self._variable_names))
        self._outputs = outputs

    def get_param_names(self):
        """Returns the parameter names.
        """
        return self._param_names

    def get_unfixed_param_names(self):
        """Returns the unfixed parameters
        """
        output_list = self._param_names.copy()
        for fixed_param in self._fixed_params.keys():
            output_list.remove(fixed_param)
        return output_list

    def n_outputs(self):
        """Returns number of model outputs, default to just V and c
        """
        return len(self._outputs)

    def n_parameters(self):
        """Returns number of parameters to be inferred, i.e. all non-fixed parameters.
        """
        return len(self._param_names) - len(self._fixed_params)

    def n_fixed_parameters(self):
        """Returns number of parameters we fix.
        """
        return len(self._fixed_params)

    def simulate(self, parameters, times):
        """This inherits from pints.ForwardModel, performs one forward simulation of the model.
        The list `parameters` contains only the parameters we are inferring.
        """
        g_Na, g_NaC, g_K1, g_K2, g_x, g_Ca, V_Na, V_K1, V_K2, V_K3, V_x1, V_x2, V_Ca = self._get_all_params(parameters)
        t_span = [times[0], times[len(times) - 1]]
        y0 = self._initial_conditions
        sol = si.solve_ivp(fun=self._rhs, t_span=t_span, y0=y0, 
                           t_eval=times, args=(g_Na, g_NaC, g_K1, g_K2, g_x, g_Ca, 
                                               V_Na, V_K1, V_K2, V_K3, V_x1, V_x2, V_Ca,
                                               self._stim_start, self._stim_period, self._stim_duration, self._stim_amplitude))

        # Now we find which outputs we wish to use
        output_indices = [self._variable_names.index(variable) for variable in self._outputs]
        return np.array([sol.y[index, :] for index in output_indices]).transpose()

    def _get_all_params(self, parameters):
        """We need a list of 13 parameters, so we check to see which parameters are fixed, and which are not.
        We increment j each time a non-fixed parameter is reached.
        """
        all_parameters = []
        j = 0
        for param in self._param_names:
            if param in self._fixed_params.keys():
                all_parameters.append(self._fixed_params[param])
            else:
                all_parameters.append(parameters[j])
                j += 1
        return tuple(all_parameters)

    @staticmethod
    def _rhs(t, y, g_Na, g_NaC, g_K1, g_K2, g_x, g_Ca, 
             V_Na, V_K1, V_K2, V_K3, V_x1, V_x2, V_Ca,
             stim_start, stim_period, stim_duration, stim_amplitude):
        """The right hand side function of the Beeler-Reuter system.
        """
        # Variables
        V, m, h, j, d, f, x, c = tuple(list(y))

        # Currents
        I_Na = (g_Na * (m**3) * h * j + g_NaC) * (V - V_Na)
        I_K = g_K1 * (exp(0.04 * (V - V_K1)) - 1) / (exp(0.08 * (V - V_K2)) + exp(0.04 * (V - V_K2))) + g_K2 * (V - V_K3) / (1 - exp(-0.04 * (V - V_K3)))
        I_x = g_x * x * (exp(0.04 * (V - V_x1)) - 1) / exp(0.04 * (V - V_x2))
        I_Ca = g_Ca * d * f * (V - V_Ca + 13.0287 * (log(c) - 7 * log(10)))

        # Stimulation parameters
        if (t - stim_start) % stim_period <= stim_duration:
            I_stim = stim_amplitude
        else:
            I_stim = 0

        # Membrane potential ODE
        V_dot = - (I_Na + I_K + I_x + I_Ca) + I_stim

        # Gating variable ODEs
        m_dot = (V + 47) / (1 - exp(-0.1 * (V + 47))) * (1 - m) - 40 * exp(-0.056 * (V + 72)) * m
        h_dot = 0.126 * exp(-0.25 * (V + 77)) * (1 - h) - 1.7 / (1 + exp(-0.082 * (V + 22.5))) * h
        j_dot = 0.055 * exp(-0.25 * (V + 78)) / (1 + exp(-0.2 * (V + 78))) * (1 - j) - 0.3 / (1 + exp(-0.1 * (V + 32))) * j
        d_dot = 0.095 * exp(-0.01 * (V + -5)) / (exp(-0.072 * (V + -5)) + 1) * (1 - d) - 0.07 * exp(-0.017 * (V + 44)) / (exp(0.05 * (V + 44)) + 1) * d
        f_dot = 0.012 * exp(-0.008 * (V + 28)) / (exp(0.15 * (V + 28)) + 1) * (1 - f) - 0.0065 * exp(-0.02 * (V + 30)) / (exp(-0.2 * (V + 30)) + 1) * f
        x_dot = 0.0005 * exp(0.083 * (V + 50)) / (exp(0.057 * (V + 50)) + 1) * (1 - x) - 0.0013 * exp(-0.06 * (V + 20)) / (exp(-0.04 * (V + 20)) + 1) * x

        # Calcium concentration ODE
        c_dot = 0.07 * (1 - c) - I_Ca
        return np.array([V_dot, m_dot, h_dot, j_dot, d_dot, f_dot, x_dot, c_dot])

# %% [markdown]
# ## Generating data for the model

# %% [markdown]
# ### Simulating the system

# %% [markdown]
# Next, we will generate some data for the model using known parameter values. We use the ones chosen by Keener and Sneyd (pg 150) [$^{[1]}$](#Sources), tabulated below:

# %% [markdown]
# |parameter|value|
# |-----|-----|
# |$g_{Na}$|4|
# |$g_{NaC}$|0.003|
# |$g_{K_1}$|1.4|
# |$g_{K_2}$|0.07|
# |$g_{x}$|0.8|
# |$g_{Ca}$|0.09|
# |$V_{Na}$|50|
# |$V_{K_1}$|-85|
# |$V_{K_2}$|-53|
# |$V_{K_3}$|-23|
# |$V_{x_1}$|-77|
# |$V_{x_2}$|-35|
# |$V_{Ca}$|-82.3|

# %% [markdown]
# The below stimulation parameters are related to ones chosen in CellML [$^{[3]}$](#Sources).

# %% [markdown]
# Conductances: $g_{Na},$ $g_{NaC},$ $g_{K_1},$ $g_{K_2},$ $g_{x},$ $g_{Ca}$
#
# Nernst potentials and other potential constants: $V_{Na},$ $V_{K_1},$ $V_{K_2},$ $V_{K_3},$ $V_{x_1},$ $V_{x_2},$ $V_{Ca}$

# %%
# Here we fix the potentials
fixed_params = {"V_Na": 50, "V_K1": -85, "V_K2": -53, "V_K3": -23, "V_x1": -77, "V_x2": -35, "V_Ca": -82.3}
# fixed_params = None
# Stimulation parameters [stim_start, stim_period, stim_duration, stim_amplitude]
stim_params = [1, 1000, 1, 25]

# %%
model = BeelerReuterModel(initial_conditions, stim_params, fixed_params=fixed_params, outputs=["V"])
param_names = model.get_unfixed_param_names()
print(param_names)
parameters = np.array([4, 0.003, 1.4, 0.07, 0.8, 0.09])
times = np.arange(0, 400, 4)
data = model.simulate(parameters, times)
# Out:
# ['g_Na', 'g_NaC', 'g_K1', 'g_K2', 'g_x', 'g_Ca']

# %% [markdown]
# ### Adding noise to the system

# %% [markdown]
# We now utilise PINTS noise generators to create some noisy data for the system. Specifically, `pints.noise.independent`
# creates independent Gaussian noise iid $\mathcal{N}(0, \sigma)$.

# %%
# sigma = 1
# noisy_data = data + pints.noise.independent(sigma, data.shape)

# %% [markdown]
# ### Plotting time series and phase plane

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
noisy_df = pd.DataFrame(noisy_data, columns=["V"])
noisy_df.to_csv("simulation_outputs/noisy_data_V.csv")

# %%
noisy_data = pd.read_csv("simulation_outputs/noisy_data_V.csv", index_col=0).to_numpy()
# V, c = data[:, 0], data[:, 1]
V = data[:, 0]
# noisy_V, noisy_c = noisy_data[:, 0], noisy_data[:, 1]
noisy_V = noisy_data[:, 0]
plt.plot(times, V, "-r", label="Without noise")
plt.plot(times, noisy_V, "-b", alpha=0.5, label="With noise")
plt.xlabel("Time [ms]")
plt.ylabel("Potential [mV]")
plt.legend()
plt.title("Membrane potential")
plt.savefig("simulation_outputs/time_series_V_only.png")

# %%
plt.plot(times, c, label="Without noise")
plt.plot(times, noisy_c, label="With noise")
plt.xlabel("Time [ms]")
plt.ylabel("Concentration [1e-7 mol/L]")
plt.legend()
plt.title("Ca2+ concentration")
plt.savefig("simulation_outputs/time_series_c.png")

# %% [markdown]
# ## Using PINTS to perform inference

# %% [markdown]
# We will now perform Bayesian inference on the model to try and recover the values of the input parameters. Here, we use the CMAES-ACMC
# combination by optimising the problem first to find starting parameters with CMAES and then using ACMC to perform Bayesian inference
# on the parameters.

# %% [markdown]
# ### Optimisation using `pints.CMAES`

# %% [markdown]
# We first use the optimiser to reach some realistic parameter values for the noisy data.

# %%
problem = pints.MultiOutputProblem(model, times, noisy_data)
score = pints.SumOfSquaresError(problem)

# %% [markdown]
# Next, choose some boundaries for the parameters. We know the signs of the Nernst potentials, as K$^{+}$ flows out of the cell
# and Na$^{+}$, Ca$^{2+}$ flow into the cell. For the conductances, we assume that we can know their order of magnitude.

# %%
boundaries = pints.RectangularBoundaries([0, 0, 0, 0, 0, 0],
                                        [10, 0.1, 10, 1, 1, 1])
log_prior = pints.UniformLogPrior(boundaries)
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\629715680.py:3: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   log_prior = pints.UniformLogPrior(boundaries)

# %%
num_opts = 10

# %% [markdown]
# And here we perform the optimisation. We choose to run this `num_opts` times to try and find the optimal solution of the different
# optimised parameters. Each optimisation is deemed complete if the objective function has not changed by more than $10^{-8}$ over a
# period of $200$ iterations. We save the parameters from each optimisation to a .csv file.

# %%
for j in range(3, num_opts):
    xs = log_prior.sample(1)
    sigma = [0.1, 0.001, 0.1, 0.01, 0.01, 0.01]
    # transform = pints.RectangularBoundariesTransformation(boundaries)
    opt = pints.OptimisationController(score, xs, sigma, boundaries, method=pints.CMAES)
    opt.set_max_unchanged_iterations(200, 0.00000001)
    opt_params, opt_values = opt.run()
    opt_param_df = pd.DataFrame({param_names[i]: [opt_params[i]] for i in range(model.n_parameters())})
    opt_param_df.to_csv(f"optimisation_outputs/parameters_V/conductances_{j}.csv")
# Out:
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 9
# Iter. Eval. Best      Current   Time m:s
# 0     9      430310.1  430310.1   0:20.0
# 1     18     427871.7  427871.7   0:39.3
# 2     27     424037.5  424037.5   0:56.5
# 3     36     417997.8  417997.8   1:13.1
# 20    189    13123.22  13123.22   5:13.3
# 40    369    10268.99  10268.99   8:49.3
# 60    549    9561.443  9561.443  12:37.5
# 80    729    9034.245  9125.811  16:27.1
# 100   909    8717.291  8725.459  20:22.0
# 120   1089   7373.745  7373.745  24:21.3
# 140   1269   3997.902  3997.902  28:24.8
# 160   1449   2761.716  2782.448  32:35.7
# 180   1629   2075.182  2075.182  37:01.1
# 200   1809   1571.919  1571.919  41:30.6
# 220   1989   1513.169  1516.73   45:57.6
# 240   2169   1476.385  1481.142  50:28.3
# 260   2349   1470.104  1471.025  55:03.4
# 280   2529   1467.172  1467.391  59:40.7
# 300   2709   1466.287  1466.287  64:17.6
# 320   2889   1466.082  1466.082  68:56.1
# 340   3069   1466.062  1466.07   73:37.2
# 360   3249   1466.056  1466.058  78:14.1
# 380   3429   1466.055  1466.055  82:48.9
# 400   3609   1466.055  1466.055  87:28.4
# 420   3789   1466.055  1466.055  92:03.3
# 780   7029   2673.015  2673.015 204:01.9
# 800   7209   2673.015  2673.015 209:30.6
# 820   7389   2673.015  2673.015 214:19.3
# 840   7569   2673.015  2673.015 219:06.1
# 860   7749   2673.015  2673.015 224:18.9
# 880   7929   2673.015  377373.2 229:56.8
# 900   8109   2673.015  2673.015 234:39.5
# 920   8289   2673.015  2673.015 239:05.3
# 940   8469   2673.015  2673.015 243:33.8
# 952   8568   2673.015  2673.015 246:02.8
# Halting: No significant change for 200 iterations.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 9
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\4159701251.py:94: RuntimeWarning: overflow encountered in scalar multiply
#   I_Na = (g_Na * (m**3) * h * j + g_NaC) * (V - V_Na)
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\4159701251.py:95: RuntimeWarning: overflow encountered in exp
#   I_K = g_K1 * (exp(0.04 * (V - V_K1)) - 1) / (exp(0.08 * (V - V_K2)) + exp(0.04 * (V - V_K2))) + g_K2 * (V - V_K3) / (1 - exp(-0.04 * (V - V_K3)))
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\4159701251.py:95: RuntimeWarning: invalid value encountered in scalar divide
#   I_K = g_K1 * (exp(0.04 * (V - V_K1)) - 1) / (exp(0.08 * (V - V_K2)) + exp(0.04 * (V - V_K2))) + g_K2 * (V - V_K3) / (1 - exp(-0.04 * (V - V_K3)))
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\4159701251.py:96: RuntimeWarning: overflow encountered in exp
#   I_x = g_x * x * (exp(0.04 * (V - V_x1)) - 1) / exp(0.04 * (V - V_x2))
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\4159701251.py:96: RuntimeWarning: invalid value encountered in scalar divide
#   I_x = g_x * x * (exp(0.04 * (V - V_x1)) - 1) / exp(0.04 * (V - V_x2))
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\4159701251.py:112: RuntimeWarning: overflow encountered in exp
#   d_dot = 0.095 * exp(-0.01 * (V + -5)) / (exp(-0.072 * (V + -5)) + 1) * (1 - d) - 0.07 * exp(-0.017 * (V + 44)) / (exp(0.05 * (V + 44)) + 1) * d
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\4159701251.py:113: RuntimeWarning: overflow encountered in exp
#   f_dot = 0.012 * exp(-0.008 * (V + 28)) / (exp(0.15 * (V + 28)) + 1) * (1 - f) - 0.0065 * exp(-0.02 * (V + 30)) / (exp(-0.2 * (V + 30)) + 1) * f
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\4159701251.py:114: RuntimeWarning: overflow encountered in exp
#   x_dot = 0.0005 * exp(0.083 * (V + 50)) / (exp(0.057 * (V + 50)) + 1) * (1 - x) - 0.0013 * exp(-0.06 * (V + 20)) / (exp(-0.04 * (V + 20)) + 1) * x
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\4159701251.py:114: RuntimeWarning: invalid value encountered in scalar divide
#   x_dot = 0.0005 * exp(0.083 * (V + 50)) / (exp(0.057 * (V + 50)) + 1) * (1 - x) - 0.0013 * exp(-0.06 * (V + 20)) / (exp(-0.04 * (V + 20)) + 1) * x
# Iter. Eval. Best      Current   Time m:s
# 0     9      345950.3  345950.3   0:13.3
# 1     18     343780.2  343780.2   0:26.2
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\4159701251.py:109: RuntimeWarning: overflow encountered in exp
#   m_dot = (V + 47) / (1 - exp(-0.1 * (V + 47))) * (1 - m) - 40 * exp(-0.056 * (V + 72)) * m
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\4159701251.py:110: RuntimeWarning: overflow encountered in exp
#   h_dot = 0.126 * exp(-0.25 * (V + 77)) * (1 - h) - 1.7 / (1 + exp(-0.082 * (V + 22.5))) * h
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\4159701251.py:111: RuntimeWarning: overflow encountered in exp
#   j_dot = 0.055 * exp(-0.25 * (V + 78)) / (1 + exp(-0.2 * (V + 78))) * (1 - j) - 0.3 / (1 + exp(-0.1 * (V + 32))) * j
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\4159701251.py:111: RuntimeWarning: invalid value encountered in scalar divide
#   j_dot = 0.055 * exp(-0.25 * (V + 78)) / (1 + exp(-0.2 * (V + 78))) * (1 - j) - 0.3 / (1 + exp(-0.1 * (V + 32))) * j
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\4159701251.py:94: RuntimeWarning: overflow encountered in scalar power
#   I_Na = (g_Na * (m**3) * h * j + g_NaC) * (V - V_Na)
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\4159701251.py:109: RuntimeWarning: overflow encountered in scalar multiply
#   m_dot = (V + 47) / (1 - exp(-0.1 * (V + 47))) * (1 - m) - 40 * exp(-0.056 * (V + 72)) * m
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\4159701251.py:110: RuntimeWarning: invalid value encountered in scalar multiply
#   h_dot = 0.126 * exp(-0.25 * (V + 77)) * (1 - h) - 1.7 / (1 + exp(-0.082 * (V + 22.5))) * h
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\4159701251.py:95: RuntimeWarning: divide by zero encountered in scalar divide
#   I_K = g_K1 * (exp(0.04 * (V - V_K1)) - 1) / (exp(0.08 * (V - V_K2)) + exp(0.04 * (V - V_K2))) + g_K2 * (V - V_K3) / (1 - exp(-0.04 * (V - V_K3)))
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\4159701251.py:112: RuntimeWarning: invalid value encountered in scalar divide
#   d_dot = 0.095 * exp(-0.01 * (V + -5)) / (exp(-0.072 * (V + -5)) + 1) * (1 - d) - 0.07 * exp(-0.017 * (V + 44)) / (exp(0.05 * (V + 44)) + 1) * d
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\4159701251.py:113: RuntimeWarning: invalid value encountered in scalar divide
#   f_dot = 0.012 * exp(-0.008 * (V + 28)) / (exp(0.15 * (V + 28)) + 1) * (1 - f) - 0.0065 * exp(-0.02 * (V + 30)) / (exp(-0.2 * (V + 30)) + 1) * f
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\4159701251.py:114: RuntimeWarning: invalid value encountered in scalar multiply
#   x_dot = 0.0005 * exp(0.083 * (V + 50)) / (exp(0.057 * (V + 50)) + 1) * (1 - x) - 0.0013 * exp(-0.06 * (V + 20)) / (exp(-0.04 * (V + 20)) + 1) * x
# 2     27     335864.1  335864.1   0:38.4
# 3     36     317524.6  317524.6   0:50.0
# 20    189    122636.2  122636.2   3:02.1
# 40    369    31401.19  39661      7:53.2
# 60    549    2027.481  4054.207  13:59.3
# 80    729    865.4339  2287.835  20:01.3
# 100   909    565.913   575.9859  26:13.8
# 120   1089   476.2017  476.2017  32:45.0
# 140   1269   452.2408  452.8221  39:17.0
# 160   1449   444.0998  444.2991  45:47.7
# 180   1629   441.9032  441.9032  52:18.1
# 200   1809   441.1213  441.1384  58:45.2
# 220   1989   441.005   441.017   65:16.7
# 240   2169   440.9864  440.9864  71:46.7
# 260   2349   440.9753  440.9755  78:11.7
# 280   2529   440.9134  440.9134  83:10.0
# 300   2709   440.7185  440.7185  88:11.3
# 320   2889   440.6982  440.6982  93:06.6
# 340   3069   440.696   440.6962  98:03.3
# 360   3249   440.6957  440.6957 102:58.1
# 380   3429   440.6956  440.6956 107:55.1
# 400   3609   440.6956  440.6956 112:49.3
# 420   3789   440.6956  440.6956 117:45.7
# 440   3969   440.6956  440.6956 122:40.6
# 460   4149   440.6956  440.6956 127:35.7
# 480   4329   440.6956  440.6956 132:31.5
# 120   1089   702.757   715.8693  27:40.4
# 140   1269   678.2426  685.3265  33:06.7
# 160   1449   637.9598  637.9598  38:31.5
# 180   1629   570.56    573.5687  44:14.3
# 200   1809   505.0629  505.9277  49:39.8
# 220   1989   483.2791  483.7826  55:11.0
# 240   2169   473.5171  477.8846  60:50.5
# 260   2349   438.5445  438.5445  66:26.2
# 280   2529   419.3434  420.3651  71:50.5
# 300   2709   417.7299  418.1609  77:01.3
# 320   2889   417.5612  417.5707  82:23.1
# 340   3069   417.3196  417.3196  87:41.9
# 360   3249   417.0984  417.129   92:59.4
# 380   3429   417.031   417.0354  98:24.8
# 400   3609   417.0213  417.0217 103:57.4
# 420   3789   417.0203  417.0203 109:26.0
# 440   3969   417.0202  417.0202 115:23.2
# 460   4149   417.0202  417.0202 121:21.7
# 480   4329   417.0202  417.0202 127:07.2
# 500   4509   417.0202  417.0202 132:48.4
# 520   4689   417.0202  417.0202 138:27.3
# 540   4869   417.0202  417.0202 144:22.4
# 560   5049   417.0202  417.0202 150:06.1
# 580   5229   417.0202  417.0202 155:18.7
# 600   5409   417.0202  417.0202 161:19.4
# 620   5589   417.0202  417.0202 167:53.5
# 640   5769   417.0202  417.0202 174:08.0
# 660   5949   417.0202  417.0202 180:41.6
# 680   6129   417.0202  417.0202 187:33.9
# 700   6309   417.0202  423684   194:24.7
# 720   6489   417.0202  417.0203 201:19.7
# 740   6669   417.0202  417.0202 207:01.4
# 760   6849   417.0202  417.0202 212:30.4
# 778   7002   417.0202  417.0202 216:51.3
# Halting: No significant change for 200 iterations.

# %% [markdown]
# If the optimisation has not converged, but has a sufficiently low score, we will take the parameters at this stage.

# %%
opt_params = opt.optimiser().x_best()
# opt_params = (boundaries.lower() + boundaries.upper()*exp(transformed_opt_params))/(1 + exp(transformed_opt_params))

# %% [markdown]
# Save these parameters to a .csv file and then read from the file afterwards.

# %%
import pandas as pd

# %%
opt_param_df = pd.DataFrame({param_names[i]: [opt_params[i]] for i in range(model.n_parameters())})
opt_param_df.to_csv(f"optimisation_outputs/parameters_V/conductances_{2}.csv")

# %% [markdown]
# ### Plotting with optimised parameters

# %%
opt_params = []
num_opts = 10
for j in range(num_opts):
    opt_param_df = pd.read_csv(f"optimisation_outputs/parameters_V/conductances_{j}.csv", index_col=0)
    opt_params.append(opt_param_df.to_numpy()[0])

# %%
errors = []
for j in range(num_opts):
    print("---------------------------------------------------------------------------")
    error = score(opt_params[j])
    print(f"Optimisation {j}, sum of squared errors = {round(error, 5)}")
    print("---------------------------------------------------------------------------")
    errors.append(error)
    for i in range(model.n_parameters()):
        print(f"Parameter: {param_names[i]}, True: {parameters[i]}, Optimised: {round(opt_params[j][i], 5)}")
# Out:
# ---------------------------------------------------------------------------
# Optimisation 0, sum of squared errors = 759.8738948928257
# ---------------------------------------------------------------------------
# Parameter: g_Na, True: 4.0, Optimised: 10.0
# Parameter: g_NaC, True: 0.003, Optimised: 0.00123
# Parameter: g_K1, True: 1.4, Optimised: 1.87573
# Parameter: g_K2, True: 0.07, Optimised: 0.12317
# Parameter: g_x, True: 0.8, Optimised: 1.0
# Parameter: g_Ca, True: 0.09, Optimised: 0.16068
# ---------------------------------------------------------------------------
# Optimisation 1, sum of squared errors = 229229.0487590956
# ---------------------------------------------------------------------------
# Parameter: g_Na, True: 4.0, Optimised: 1.30252
# Parameter: g_NaC, True: 0.003, Optimised: 0.04744
# Parameter: g_K1, True: 1.4, Optimised: 5.288
# Parameter: g_K2, True: 0.07, Optimised: 0.10545
# Parameter: g_x, True: 0.8, Optimised: 0.42029
# Parameter: g_Ca, True: 0.09, Optimised: 0.70368
# ---------------------------------------------------------------------------
# Optimisation 2, sum of squared errors = 1165.6637749411257
# ---------------------------------------------------------------------------
# Parameter: g_Na, True: 4.0, Optimised: 6.61746
# Parameter: g_NaC, True: 0.003, Optimised: 0.03713
# Parameter: g_K1, True: 1.4, Optimised: 6.1117
# Parameter: g_K2, True: 0.07, Optimised: 0.18126
# Parameter: g_x, True: 0.8, Optimised: 1.0
# Parameter: g_Ca, True: 0.09, Optimised: 0.23007
# ---------------------------------------------------------------------------
# Optimisation 3, sum of squared errors = 1466.0551918629592
# ---------------------------------------------------------------------------
# Parameter: g_Na, True: 4.0, Optimised: 7.2696
# Parameter: g_NaC, True: 0.003, Optimised: 0.04653
# Parameter: g_K1, True: 1.4, Optimised: 7.36811
# Parameter: g_K2, True: 0.07, Optimised: 0.20367
# Parameter: g_x, True: 0.8, Optimised: 1.0
# Parameter: g_Ca, True: 0.09, Optimised: 0.25957
# ---------------------------------------------------------------------------
# Optimisation 4, sum of squared errors = 714.0983484267605
# ---------------------------------------------------------------------------
# Parameter: g_Na, True: 4.0, Optimised: 5.59292
# Parameter: g_NaC, True: 0.003, Optimised: 0.02353
# Parameter: g_K1, True: 1.4, Optimised: 4.15151
# Parameter: g_K2, True: 0.07, Optimised: 0.14169
# Parameter: g_x, True: 0.8, Optimised: 1.0
# Parameter: g_Ca, True: 0.09, Optimised: 0.17848
# ---------------------------------------------------------------------------
# Optimisation 5, sum of squared errors = 7085.872272469356
# ---------------------------------------------------------------------------
# Parameter: g_Na, True: 4.0, Optimised: 6.22347
# Parameter: g_NaC, True: 0.003, Optimised: 0.03784
# Parameter: g_K1, True: 1.4, Optimised: 5.95887
# Parameter: g_K2, True: 0.07, Optimised: 0.17313
# Parameter: g_x, True: 0.8, Optimised: 1.0
# Parameter: g_Ca, True: 0.09, Optimised: 0.2169
# ---------------------------------------------------------------------------
# Optimisation 6, sum of squared errors = 2673.0147661007063
# ---------------------------------------------------------------------------
# Parameter: g_Na, True: 4.0, Optimised: 5.2482
# Parameter: g_NaC, True: 0.003, Optimised: 0.07488
# Parameter: g_K1, True: 1.4, Optimised: 10.0
# Parameter: g_K2, True: 0.07, Optimised: 0.21758
# Parameter: g_x, True: 0.8, Optimised: 1.0
# Parameter: g_Ca, True: 0.09, Optimised: 0.26819
# ---------------------------------------------------------------------------
# Optimisation 7, sum of squared errors = 9454.876470607316
# ---------------------------------------------------------------------------
# Parameter: g_Na, True: 4.0, Optimised: 8.68001
# Parameter: g_NaC, True: 0.003, Optimised: 0.0077
# Parameter: g_K1, True: 1.4, Optimised: 2.37146
# Parameter: g_K2, True: 0.07, Optimised: 0.12346
# Parameter: g_x, True: 0.8, Optimised: 1.0
# Parameter: g_Ca, True: 0.09, Optimised: 0.15745
# ---------------------------------------------------------------------------
# Optimisation 8, sum of squared errors = 148.086619511882
# ---------------------------------------------------------------------------
# Parameter: g_Na, True: 4.0, Optimised: 4.14771
# Parameter: g_NaC, True: 0.003, Optimised: 0.00101
# Parameter: g_K1, True: 1.4, Optimised: 1.06125
# Parameter: g_K2, True: 0.07, Optimised: 0.06178
# Parameter: g_x, True: 0.8, Optimised: 0.73893
# Parameter: g_Ca, True: 0.09, Optimised: 0.07764
# ---------------------------------------------------------------------------
# Optimisation 9, sum of squared errors = 417.02020928999696
# ---------------------------------------------------------------------------
# Parameter: g_Na, True: 4.0, Optimised: 4.68559
# Parameter: g_NaC, True: 0.003, Optimised: 0.01427
# Parameter: g_K1, True: 1.4, Optimised: 2.80391
# Parameter: g_K2, True: 0.07, Optimised: 0.11013
# Parameter: g_x, True: 0.8, Optimised: 1.0
# Parameter: g_Ca, True: 0.09, Optimised: 0.13995

# %%
chosen_opt = 8

# %%
opt_soln = model.simulate(opt_params[chosen_opt], times)
# opt_V, opt_c = opt_soln[:, 0], opt_soln[:, 1]
opt_V = opt_soln[:, 0]
plt.plot(times, opt_V, label="Optimised")
plt.plot(times, noisy_V, label="True data")
plt.xlabel("Time [ms]")
plt.ylabel("Potential [mV]")
plt.legend()
plt.title("Membrane potential")
plt.savefig(f"optimisation_outputs/time_series_V_only_{chosen_opt}.png")

# %%
plt.plot(times, opt_c, label="Optimised")
plt.plot(times, noisy_c, label="True data")
plt.xlabel("Time [ms]")
plt.ylabel("Concentration [1e-7 mol/L]")
plt.legend()
plt.title("Ca2+ concentration")
plt.savefig(f"optimisation_outputs/time_series_c_{chosen_opt}.png")

# %% [markdown]
# ### Inference using `pints.HaarioBardenetACMC`

# %%
log_likelihood = pints.GaussianLogLikelihood(problem)
composed_log_prior = pints.ComposedLogPrior(log_prior,
                                            pints.TruncatedGaussianLogPrior(0, 1, 0, np.inf),
                                            # pints.TruncatedGaussianLogPrior(0, 1, 0, np.inf)
                                           )
log_posterior = pints.LogPosterior(log_likelihood, composed_log_prior)

# %% [markdown]
# ### Initialising chains

# %% [markdown]
# Here, we initialise the chain with the optimised parameters. We only need one chain for our purpose as we use
# parameters close to the true value.

# %%
# xs = np.tile(np.array(opt_params[chosen_opt].tolist() + [1] + [1]), (1, 1))
xs = np.tile(np.array(opt_params[chosen_opt].tolist() + [1]), (1, 1))
num_chains = 1
# transform = pints.RectangularBoundariesTransformation([0, 0, 0, 0, 0, 0, 0, 0],
#                                         [10, 1, 10, 1, 1, 1, 10, 10])
transform = pints.RectangularBoundariesTransformation([0, 0, 0, 0, 0, 0, 0],
                                        [10, 1, 10, 1, 1, 1, 10])

# %% [markdown]
# ### Performing inference

# %%
n_params = log_prior.n_parameters()
mcmc = pints.MCMCController(log_posterior, num_chains, xs, method=pints.HaarioBardenetACMC, transformation=transform)
max_iterations = 20000
mcmc.set_max_iterations(max_iterations)
# mcmc.set_parallel(True)
# print(mcmc.parallel())

chains = mcmc.run()
# Out:
# Using Haario-Bardenet adaptive covariance MCMC
# Generating 1 chains.
# Running in sequential mode.
# Iter. Eval. Accept.   Time m:s
# 0     1      0          0:01.6
# 1     2      0          0:03.1
# 2     3      0          0:04.7
# 3     4      0          0:07.4
# 20    21     0          0:40.3
# 40    41     0          1:23.5
# 60    61     0          2:01.8
# 80    81     0          2:41.1
# 100   101    0          3:23.4
# 120   121    0          4:02.6
# 140   141    0          4:45.6
# 160   161    0          5:25.4
# 180   181    0          6:00.1
# Initial phase completed.
# 200   201    0          6:38.8
# 220   221    0.00452    7:12.8
# 240   241    0.0415     7:45.7
# 260   261    0.0996     8:18.4
# 280   281    0.132      8:52.6
# 300   301    0.156      9:25.8
# 320   321    0.165109   9:59.1
# 340   341    0.161     10:32.3
# 360   361    0.169     11:06.4
# 380   381    0.167979  11:39.8
# 400   401    0.17      12:13.8
# 420   421    0.171     12:47.0
# 440   441    0.19      13:20.3
# 460   461    0.195     13:54.3
# 480   481    0.204     14:28.5
# 500   501    0.204     15:01.3
# 520   521    0.203     15:34.2
# 540   541    0.2       16:07.5
# 560   561    0.197861  16:40.7
# 580   581    0.198     17:13.8
# 600   601    0.196     17:47.1
# 620   621    0.198     18:20.1
# 640   641    0.197     18:58.3
# 660   661    0.195     19:33.4
# 5820  5821   0.209    173:56.4
# 5840  5841   0.209    174:32.4
# 5860  5861   0.208    175:08.0
# 5880  5881   0.208    175:42.1
# 5900  5901   0.208    176:16.2
# 5920  5921   0.207    176:51.2
# 5940  5941   0.207    177:25.8
# 5960  5961   0.207    178:00.2
# 5980  5981   0.207    178:34.4
# 6000  6001   0.208    179:08.9
# 6020  6021   0.207    179:43.3
# 6040  6041   0.207416 180:17.4
# 6060  6061   0.208    180:53.6
# 6080  6081   0.208    181:27.8
# 6100  6101   0.208    182:02.4
# 6120  6121   0.208    182:36.8
# 6140  6141   0.209    183:11.2
# 6160  6161   0.20857  183:45.6
# 6180  6181   0.208    184:22.5
# 6200  6201   0.208031 184:57.1
# 6220  6221   0.208    185:32.3
# 6240  6241   0.207    186:07.1
# 6260  6261   0.207954 186:41.5
# 6280  6281   0.208    187:16.6
# 6300  6301   0.208    187:52.1
# 6320  6321   0.208    188:26.5
# 6340  6341   0.208    189:01.5
# 6360  6361   0.208    189:35.7
# 6380  6381   0.208    190:09.6
# 6400  6401   0.208    190:44.1
# 6420  6421   0.208    191:23.1
# 6440  6441   0.208    191:58.7
# 6460  6461   0.208    192:32.7
# 6480  6481   0.208    193:06.3
# 6500  6501   0.208    193:40.6
# 6520  6521   0.207    194:18.1
# 6540  6541   0.208    194:52.9
# 6560  6561   0.208    195:32.9
# 6580  6581   0.208    196:07.7
# 6600  6601   0.207    196:42.0
# 6620  6621   0.207    197:16.3
# 6640  6641   0.207    197:50.5
# 6660  6661   0.207    198:24.8
# 6680  6681   0.207454 198:59.0
# 6700  6701   0.207581 199:34.6
# 6720  6721   0.208    200:09.6
# 6740  6741   0.207981 200:43.6
# 6760  6761   0.208    201:17.7
# 6780  6781   0.209    201:52.0
# 6800  6801   0.209    202:25.9
# 6820  6821   0.209    202:59.8
# 6840  6841   0.209    203:39.2
# 6860  6861   0.209    204:16.1
# 6880  6881   0.209    204:50.0
# 6900  6901   0.209    205:23.9
# 6920  6921   0.209    205:59.2
# 6940  6941   0.208    206:33.3
# 6960  6961   0.208    207:07.3
# 6980  6981   0.208    207:41.2
# 7000  7001   0.208    208:15.1
# 7020  7021   0.208    208:50.7
# 7040  7041   0.207925 209:24.9
# 7060  7061   0.207    209:58.3
# 7080  7081   0.207    210:32.5
# 7100  7101   0.207    211:07.5
# 7120  7121   0.207    211:41.5
# 7140  7141   0.207    212:15.5
# 7160  7161   0.207094 212:50.6
# 7180  7181   0.207    213:24.7
# 7200  7201   0.208    213:58.9
# 7220  7221   0.208    214:34.5
# 7240  7241   0.208    215:08.3
# 7260  7261   0.208    215:42.1
# 7280  7281   0.208    216:16.3
# 7300  7301   0.209    216:57.7
# 7320  7321   0.209    217:32.0
# 7340  7341   0.209    218:06.2
# 7360  7361   0.20989  218:40.6
# 7380  7381   0.21     219:15.2
# 7400  7401   0.211    219:49.5
# 7420  7421   0.21     220:23.6
# 7440  7441   0.21     220:57.7
# 7460  7461   0.21     221:32.0
# 7480  7481   0.209464 222:07.0
# 7500  7501   0.209    222:41.0
# 10940 10941  0.218    325:14.1
# 10960 10961  0.218    325:48.3
# 10980 10981  0.218    326:23.6
# 11000 11001  0.218    326:58.8
# 11020 11021  0.218129 327:35.1
# 11040 11041  0.218549 328:10.2
# 11060 11061  0.219    328:46.1
# 11080 11081  0.219    329:21.7
# 11100 11101  0.219    329:57.1
# 11120 11121  0.219135 330:34.3
# 11140 11141  0.219    331:11.3
# 11160 11161  0.219    331:48.4
# 11180 11181  0.22     332:23.1
# 11200 11201  0.22     332:58.2
# 11220 11221  0.221    333:33.8
# 11240 11241  0.221    334:11.9
# 11260 11261  0.221    334:47.0
# 11280 11281  0.220991 335:22.1
# 11300 11301  0.221    335:57.7
# 11320 11321  0.221    336:32.9
# 11340 11341  0.221    337:08.8
# 11360 11361  0.221    337:44.2
# 11380 11381  0.221    338:22.9
# 11400 11401  0.220507 338:58.6
# 11420 11421  0.22     339:35.7
# 11440 11441  0.22     340:11.7
# 11460 11461  0.22     340:47.1
# 11480 11481  0.22     341:22.7
# 11500 11501  0.22     341:58.6
# 11520 11521  0.22     342:34.4
# 11540 11541  0.22     343:08.9
# 11560 11561  0.22     343:47.9
# 11580 11581  0.22     344:26.2
# 11600 11601  0.22     345:03.5
# 11620 11621  0.22     345:38.6
# 11640 11641  0.22     346:13.1
# 11660 11661  0.219    346:48.1
# 11680 11681  0.219    347:23.0
# 11700 11701  0.219    347:57.4
# 11720 11721  0.219    348:33.6
# 11740 11741  0.219    349:09.9
# 11760 11761  0.22     349:45.9
# 11780 11781  0.22     350:20.9
# 11800 11801  0.22     350:57.1
# 11820 11821  0.22     351:33.1
# 11840 11841  0.22     352:09.4
# 11860 11861  0.22     352:45.5
# 11880 11881  0.22     353:23.1
# 11900 11901  0.22     354:00.4
# 11920 11921  0.22     354:38.3
# 11940 11941  0.22     355:15.6
# 11960 11961  0.22     355:51.1
# 11980 11981  0.22     356:26.0
# 12000 12001  0.22     357:01.1
# 12020 12021  0.22     357:35.6
# 12040 12041  0.22     358:10.8
# 12060 12061  0.22     358:45.1
# 12080 12081  0.219    359:21.1
# 12100 12101  0.219486 359:56.5
# 12120 12121  0.22     360:31.1
# 12140 12141  0.22     361:05.8
# 12160 12161  0.22     361:40.3
# 12180 12181  0.22     362:15.6
# 12200 12201  0.219982 362:50.1
# 12220 12221  0.22     363:25.8
# 12240 12241  0.22     364:04.4
# 12260 12261  0.22     364:41.8
# 12280 12281  0.22     365:21.4
# 12300 12301  0.221    365:57.8
# 12320 12321  0.220599 366:34.7
# 12340 12341  0.221    367:11.0
# 12360 12361  0.220775 367:48.1
# 12380 12381  0.221    368:22.7
# 12400 12401  0.221    369:01.8
# 12420 12421  0.221    369:43.2
# 12440 12441  0.221    370:19.0
# 12460 12461  0.221    370:55.9
# 12480 12481  0.221    371:32.1
# 12500 12501  0.221    372:10.0
# 12520 12521  0.221    372:46.3
# 12540 12541  0.221    373:22.3
# 12560 12561  0.221    373:58.7
# 12580 12581  0.221    374:35.8
# 12600 12601  0.221411 375:13.4
# 12620 12621  0.221    375:49.9
# 14340 14341  0.223    428:08.1
# 14360 14361  0.223    428:45.5
# 14380 14381  0.223    429:22.6
# 14400 14401  0.222    429:58.0
# 14420 14421  0.222384 430:34.0
# 14440 14441  0.222    431:08.6
# 14460 14461  0.222253 431:42.9
# 14480 14481  0.222    432:19.6
# 14500 14501  0.222    432:53.7
# 14520 14521  0.222    433:29.9
# 14540 14541  0.222    434:07.7
# 14560 14561  0.222    434:45.1
# 14580 14581  0.222    435:19.6
# 14600 14601  0.222    435:53.9
# 14620 14621  0.222    436:29.6
# 14640 14641  0.222    437:07.5
# 14660 14661  0.221    437:43.5
# 14680 14681  0.221    438:19.8
# 14700 14701  0.221    438:57.0
# 14720 14721  0.221    439:34.9
# 14740 14741  0.221    440:11.8
# 14760 14761  0.221    440:48.0
# 14780 14781  0.221    441:23.5
# 14800 14801  0.221    442:00.1
# 14820 14821  0.221    442:37.3
# 14840 14841  0.22     443:14.9
# 14860 14861  0.22     443:51.2
# 14880 14881  0.22     444:28.7
# 14900 14901  0.22     445:04.9
# 14920 14921  0.22     445:41.5
# 14940 14941  0.22     446:17.5
# 14960 14961  0.22     446:53.2
# 14980 14981  0.22     447:30.4
# 15000 15001  0.22     448:06.0
# 15020 15021  0.22     448:41.3
# 15040 15041  0.22     449:17.7
# 15060 15061  0.22     449:55.4
# 15080 15081  0.22     450:30.9
# 15100 15101  0.22     451:07.1
# 15120 15121  0.22     451:43.7
# 15140 15141  0.22     452:20.4
# 15160 15161  0.22     453:00.1
# 15180 15181  0.22     453:37.5
# 15200 15201  0.22     454:17.5
# 15220 15221  0.22     454:55.6
# 15240 15241  0.22     455:33.9
# 15260 15261  0.22     456:14.8
# 15280 15281  0.22     456:49.9
# 15300 15301  0.22     457:26.3
# 15320 15321  0.22     458:12.5
# 15340 15341  0.22     458:48.6
# 15360 15361  0.22     459:24.7
# 15380 15381  0.22     460:01.5
# 15400 15401  0.221    460:37.7
# 15420 15421  0.22     461:14.2
# 15440 15441  0.221    461:48.5
# 15460 15461  0.221    462:24.6
# 15480 15481  0.221    463:04.8
# 15500 15501  0.221    463:45.1
# 15520 15521  0.221    464:23.4
# 15540 15541  0.22     465:01.4
# 15560 15561  0.22     465:40.0
# 15580 15581  0.22     466:17.0
# 15600 15601  0.221    466:52.7
# 15620 15621  0.221    467:30.2
# 15640 15641  0.220702 468:08.0
# 15660 15661  0.221    468:45.6
# 15680 15681  0.221    469:23.6
# 15700 15701  0.221    470:02.3
# 15720 15721  0.221    470:47.0
# 15740 15741  0.220634 471:25.0
# 15760 15761  0.22     472:01.8
# 15780 15781  0.22     472:39.5
# 15800 15801  0.22     473:16.9
# 15820 15821  0.221    473:54.2
# 15840 15841  0.221    474:31.3
# 15860 15861  0.221    475:08.4
# 15880 15881  0.22     475:44.7
# 15900 15901  0.22     476:19.8
# 15920 15921  0.22     476:56.9
# 15940 15941  0.22     477:33.6
# 15960 15961  0.22     478:10.0
# 15980 15981  0.22     478:46.9
# 16000 16001  0.221    479:23.5
# 16020 16021  0.221    480:05.8
# 16040 16041  0.221    480:41.1
# 16060 16061  0.220472 481:16.8
# 16080 16081  0.22     481:52.8
# 16100 16101  0.22     482:27.7
# 16120 16121  0.22     483:01.7
# 16140 16141  0.22     483:35.7
# 16160 16161  0.22     484:11.9
# 16180 16181  0.22     484:49.0
# 16200 16201  0.220295 485:24.7
# 16220 16221  0.22027  485:59.5
# 16240 16241  0.22     486:34.1
# 16260 16261  0.22     487:08.6
# 16280 16281  0.22     487:42.8
# 16300 16301  0.22     488:17.1
# 16320 16321  0.22     488:52.4
# 16340 16341  0.22     489:26.8
# 16360 16361  0.22     490:11.5
# 16380 16381  0.22     491:12.5
# 16400 16401  0.22     491:54.1
# 16420 16421  0.221    492:35.8
# 16440 16441  0.220607 493:14.4
# 16460 16461  0.221    493:49.4
# 16480 16481  0.221    494:25.3
# 16500 16501  0.221    495:00.5
# 16520 16521  0.221    495:34.9
# 16540 16541  0.221    496:09.4
# 16560 16561  0.22082  496:43.8
# 16580 16581  0.221    497:18.0
# 16600 16601  0.221    497:52.2
# 16620 16621  0.221    498:26.2
# 16640 16641  0.22078  499:00.4
# 16660 16661  0.221    499:35.5
# 16680 16681  0.221    500:09.9
# 16700 16701  0.220885 500:44.1
# 16720 16721  0.221    501:18.3
# 16740 16741  0.221    501:52.6
# 16760 16761  0.221    502:27.6
# 16780 16781  0.221    503:01.8
# 16800 16801  0.221    503:36.5
# 16820 16821  0.221    504:11.1
# 16840 16841  0.221    504:47.0
# 16860 16861  0.221    505:21.3
# 16880 16881  0.221    505:55.5
# 16900 16901  0.221    506:29.8
# 16920 16921  0.221    507:04.1
# 16940 16941  0.221    507:39.2
# 16960 16961  0.221    508:13.3
# 16980 16981  0.221    508:47.6
# 17000 17001  0.221    509:22.1
# 17020 17021  0.221    509:56.2
# 17040 17041  0.221    510:30.2
# 17060 17061  0.221    511:05.1
# 17080 17081  0.221    511:39.6
# 17100 17101  0.221    512:14.2
# 17120 17121  0.221    512:48.2
# 17140 17141  0.221    513:22.5
# 17160 17161  0.221    513:56.7
# 17180 17181  0.221    514:32.3
# 17200 17201  0.221    515:07.6
# 17220 17221  0.221    515:41.4
# 17240 17241  0.221    516:17.8
# 17260 17261  0.221482 516:52.5
# 17280 17281  0.221    517:26.7
# 17300 17301  0.221    518:00.8
# 17320 17321  0.221    518:35.1
# 17340 17341  0.221    519:09.2
# 17360 17361  0.221    519:43.3
# 17380 17381  0.221    520:17.7
# 17400 17401  0.221    520:52.0
# 17420 17421  0.221    521:32.0
# 17440 17441  0.221    522:05.8
# 17460 17461  0.221    522:40.4
# 17480 17481  0.221    523:14.8
# 17500 17501  0.221    523:49.0
# 17520 17521  0.221    524:24.4
# 17540 17541  0.220911 524:59.0
# 17560 17561  0.221    525:34.4
# 17580 17581  0.221    526:08.8
# 17600 17601  0.221    526:43.0
# 17620 17621  0.221    527:17.1
# 17640 17641  0.221    527:51.2
# 17660 17661  0.221052 528:25.2
# 17680 17681  0.221    528:59.8
# 17700 17701  0.221061 529:35.0
# 17720 17721  0.221    530:10.0
# 17740 17741  0.221    530:44.5
# 17760 17761  0.221    531:19.1
# 17780 17781  0.221    531:53.6
# 17800 17801  0.221    532:27.7
# 17820 17821  0.220863 533:02.1
# 17840 17841  0.221    533:36.5
# 17860 17861  0.221    534:11.5
# 17880 17881  0.221    534:45.7
# 17900 17901  0.221    535:20.0
# 17920 17921  0.221    535:54.5
# 17940 17941  0.221    536:28.5
# 17960 17961  0.221    537:02.9
# 17980 17981  0.221    537:38.5
# 18000 18001  0.221    538:12.6
# 18020 18021  0.222    538:47.2
# 18040 18041  0.221    539:21.0
# 18060 18061  0.222    539:55.3
# 18080 18081  0.221    540:29.3
# 18100 18101  0.221369 541:03.4
# 18120 18121  0.221235 541:37.4
# 18140 18141  0.221    542:11.3
# 18160 18161  0.221    542:45.9
# 18180 18181  0.221    543:20.2
# 18200 18201  0.221    543:54.5
# 18220 18221  0.221    544:30.5
# 18240 18241  0.221    545:04.9
# 18260 18261  0.22     545:39.1
# 18280 18281  0.220174 546:14.5
# 18300 18301  0.22     546:48.5
# 18320 18321  0.22     547:22.5
# 18340 18341  0.22     547:56.4
# 18360 18361  0.22     548:30.8
# 18380 18381  0.22     549:05.0
# 18400 18401  0.22     549:39.6
# 18420 18421  0.22     550:14.1
# 18440 18441  0.22     550:50.3
# 18460 18461  0.22     551:25.0
# 18480 18481  0.220118 551:59.1
# 18500 18501  0.22     552:33.3
# 18520 18521  0.22     553:07.8
# 18540 18541  0.22     553:42.5
# 18560 18561  0.22     554:17.6
# 18580 18581  0.22     554:52.3
# 18600 18601  0.22     555:26.6
# 18620 18621  0.22     556:00.4
# 18640 18641  0.22     556:34.6
# 18660 18661  0.22     557:08.6
# 18680 18681  0.22     557:42.7
# 18700 18701  0.219    558:18.7
# 18720 18721  0.22     558:53.2
# 18740 18741  0.22     559:28.2
# 18760 18761  0.219871 560:02.7
# 18780 18781  0.22     560:37.0
# 18800 18801  0.22     561:11.0
# 18820 18821  0.22     561:45.1
# 18840 18841  0.22     562:18.8
# 18860 18861  0.22     562:53.1
# 18880 18881  0.22     563:27.4
# 18900 18901  0.22     564:01.5
# 18920 18921  0.22039  564:36.2
# 18940 18941  0.22     565:10.6
# 18960 18961  0.22     565:44.3
# 18980 18981  0.22     566:18.3
# 19000 19001  0.22     566:52.6
# 19020 19021  0.22     567:26.5
# 19040 19041  0.22     568:00.8
# 19060 19061  0.22     568:35.1
# 19080 19081  0.22     569:09.1
# 19100 19101  0.22     569:42.8
# 19120 19121  0.22     570:16.7
# 19140 19141  0.22     570:51.7
# 19160 19161  0.22     571:25.8
# 19180 19181  0.22     572:04.7
# 19200 19201  0.22     572:39.1
# 19220 19221  0.221    573:13.0
# 19240 19241  0.221    573:47.4
# 19260 19261  0.220757 574:23.9
# 19280 19281  0.221    574:58.2
# 19300 19301  0.221    575:32.3
# 19320 19321  0.221    576:08.4
# 19340 19341  0.221    576:44.4
# 19360 19361  0.221    577:18.4
# 19380 19381  0.221    577:53.2
# 19400 19401  0.221    578:27.5
# 19420 19421  0.221    579:01.7
# 19440 19441  0.221    579:35.7
# 19460 19461  0.221    580:11.3
# 19480 19481  0.221    580:45.3
# 19500 19501  0.221    581:19.4
# 19520 19521  0.221    581:53.7
# 19540 19541  0.221    582:27.8
# 19560 19561  0.221    583:03.0
# 19580 19581  0.221    583:40.6
# 19600 19601  0.221    584:16.0
# 19620 19621  0.221    584:50.0
# 19640 19641  0.22117  585:24.2
# 19660 19661  0.221    585:58.2
# 19680 19681  0.221    586:32.0
# 19700 19701  0.221    587:06.1
# 19720 19721  0.221    587:40.5
# 19740 19741  0.221    588:14.7
# 19760 19761  0.221    588:48.7
# 19780 19781  0.221    589:23.7
# 19800 19801  0.222    589:58.0
# 19820 19821  0.222    590:32.3
# 19840 19841  0.222015 591:06.7
# 19860 19861  0.222    591:40.9
# 19880 19881  0.222    592:15.8
# 19900 19901  0.222    592:49.5
# 19920 19921  0.222    593:23.6
# 19940 19941  0.222    593:57.7
# 19960 19961  0.222    594:32.4
# 19980 19981  0.222    595:06.6
# 20000 20000  0.2224   595:39.0
# Halting: Maximum number of iterations (20000) reached.

# %% [markdown]
# If we haven't quite reached the limit, save the chains here.

# %%
# mcmc.set_max_iterations(5020)
# chains = mcmc.run()
# chains = mcmc.chains()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[34], line 2
#       1 mcmc.set_max_iterations(5020)
# ----> 2 chains = mcmc.run()
#       3 # chains = mcmc.chains()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pints\_mcmc\__init__.py:550, in MCMCController.run(self)
#     548 # Can only run once for each controller instance
#     549 if self._has_run:
# --> 550     raise RuntimeError("Controller is valid for single use only")
#     551 self._has_run = True
#     553 # Check stopping criteria
#
# RuntimeError: Controller is valid for single use only

# %% [markdown]
# ### Saving chains

# %%
import pandas as pd

# %%
# all_param_names = param_names + ["sigma_V", "sigma_c"]
all_param_names = param_names + ["sigma_V"]

# %%
for i, chain in enumerate(chains):
    df = pd.DataFrame(chain, columns=all_param_names)
    df.to_csv(f"chain_data/conductances_V/chain_{i}.csv")

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Recovering chains from .csv files

# %%
num_chains = 1
list_of_chains = []
for i in range(num_chains):
    df = pd.read_csv(f"chain_data/conductances_V/chain_{i}.csv", index_col=0)
    chain = df.to_numpy()
    list_of_chains.append(chain)
chains = np.array(list_of_chains)

# %% [markdown]
# ### Trace plots

# %%
import setuptools

# %%
import pints.plot
pints.plot.trace(chains, parameter_names=all_param_names)
plt.show()

# %% [markdown]
# ### Diagnosing using $\hat{R}$

# %% [markdown]
# Here we find the $\hat{R}$ measure for the inference for all different parameters. For well mixed and stationary chains, $\hat{R}$ is close to $1$.

# %%
r_hat_values = pints.rhat(chains, warm_up=0.5)
for i in range(len(all_param_names)):
    print(f"R_hat value for {all_param_names[i]}: {round(r_hat_values[i], 5)}")
# Out:
# R_hat value for g_Na: 1.00206
# R_hat value for g_NaC: 1.00052
# R_hat value for g_K1: 1.00074
# R_hat value for g_K2: 1.00198
# R_hat value for g_x: 1.00013
# R_hat value for g_Ca: 1.00126
# R_hat value for sigma_V: 1.01267

# %% [markdown]
# Next, calculate the effective sample size, a measure of how many truly independent samples the MCMC algorithm has produced.

# %%
for j, chain in enumerate(chains):
    ess = pints.effective_sample_size(chain)
    for i in range(len(all_param_names)):
        print(f"Effective sample size for chain {j}, param {all_param_names[i]} = {round(ess[i], 5)}")
# Out:
# Effective sample size for chain 0, param g_Na = 538.32779
# Effective sample size for chain 0, param g_NaC = 268.71489
# Effective sample size for chain 0, param g_K1 = 584.52927
# Effective sample size for chain 0, param g_K2 = 267.05611
# Effective sample size for chain 0, param g_x = 324.36587
# Effective sample size for chain 0, param g_Ca = 249.16881
# Effective sample size for chain 0, param sigma_V = 97.04496

# %% [markdown]
# We will now discount the first half of the iterations.

# %%
chains = chains[:, int(max_iterations / 2):]

# %%
pints.plot.trace(chains, parameter_names=all_param_names)
plt.show()

# %% [markdown]
# ### Predicted time series plots

# %% [markdown]
# #### Chain 1

# %%
pints.plot.series(chains[0, :], problem)
plt.savefig("inference_outputs/series_conductances_V.png")

# %% [markdown]
# ### Pairwise plots

# %% [markdown]
# Here we will see which parameters are most correlated.

# %%
pints.plot.pairwise(chains[0, :, :-1], parameter_names=all_param_names[:-1])
plt.savefig("inference_outputs/pairwise_conductances_V.png")

# %% [markdown]
# ## Extracting posterior distributions

# %% [markdown]
# Finally, we will use the stationary chain data to extract posteriors. Assuming chains have converged, we can use their
# iterations as samples from the posterior.

# %%
chains_df = pd.DataFrame(columns=all_param_names + ['chain'])
for i in range(num_chains):
    chain_i_df = pd.DataFrame(chains[i], columns=all_param_names)
    chain_i_df['chain'] = [i] * len(chain_i_df)
    chains_df = pd.concat([chains_df, chain_i_df], ignore_index=True)
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_13040\1106702706.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   chains_df = pd.concat([chains_df, chain_i_df], ignore_index=True)

# %%
for name in param_names:
    print(f"Mean {name}: {np.mean(chains_df[name])}," 
          f" std dev {name}: {np.std(chains_df[name])}")
histograms = chains_df.hist(column=param_names, alpha=0.7)
for i in range(3):
    for j in range(2):
        ax = histograms[i][j]
        ax.axvline(parameters[i * 2 + j], color='r', linestyle='dashed', linewidth=1, label="True")
plt.tight_layout()
plt.legend()
plt.savefig("inference_outputs/posteriors_conductances_V.png")
# Out:
# Mean g_Na: 4.171999466827809, std dev g_Na: 0.13137234471348386
# Mean g_NaC: 0.0009743172381853708, std dev g_NaC: 0.00012649383393660636
# Mean g_K1: 1.0572355210797582, std dev g_K1: 0.04402740171328041
# Mean g_K2: 0.062131983512164354, std dev g_K2: 0.0030862099065368494
# Mean g_x: 0.7459474552187949, std dev g_x: 0.036521889323649734
# Mean g_Ca: 0.07824979604586045, std dev g_Ca: 0.004210166205929029

# %% [markdown]
# ## Sources
# $^{[1]}$ J. Keener and J. Sneyd (1998) - Mathematical Physiology https://link.springer.com/book/10.1007/b98841
#
# $^{[2]}$ G. W. Beeler and H. Reuter, RECONSTRUCTION OF THE ACTION POTENTIAL OF
# VENTRICULAR MYOCARDIAL FIBRES, J. Physiol. **268** (1977), pp. 177-210 https://doi.org/10.1113/jphysiol.1977.sp011853
#
# $^{[3]}$ P. Noble, F. Fenton, cellML - Beeler, Reuter 1997, date accessed: 22/03/24, https://models.cellml.org/e/1
