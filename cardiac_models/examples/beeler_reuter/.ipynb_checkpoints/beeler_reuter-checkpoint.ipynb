# %% [markdown]
# # Inferring parameters for the Beeler-Reuter Model

# %% [markdown]
# In this notebook, we use PINTS to create noisy data for a Beeler-Reuter system and then perform inference on the model
# to try and retrieve the parameters. This should be compared with results from other notebooks, such as the FitzHugh-Nagumo
# notebook.

# %% [markdown]
# ## Creating the ForwardModel

# %% [markdown]
# ### Variable descriptions

# %% [markdown]
# Firstly, we set up the system of ODEs for the Beeler-Reuter system. Below is a description of the 8 time-dependent variables
# present in the model (which form a system of 8 ODEs), and we follow the notation of Keener and Sneyd (1998) Section 4.3 [$^{[1]}$](#Sources).

# %% [markdown]
# |variable|description|ion|
# |---|-------|---|
# |$V$|membrane potential|all|
# |$m$|fast sodium activation gating variable|$Na^{+}$|
# |$h$|fast sodium inactivation gating variable|$Na^{+}$|
# |$j$|fast sodium reactivation gating variable|$Na^{+}$|
# |$d$|slow inward calcium activation gating variable|$Ca^{2+}$|
# |$f$|slow inward calcium inactivation gating variable|$Ca^{2+}$|
# |$c$|$10^{7}[Ca]_{i}$ where $[Ca]_{i}$ is the internal calcium concentration|$Ca^{2+}$|
# |$x$|outward potassium gating variable|$K^{+}$|

# %% [markdown]
# ### Membrane potential ODE

# %% [markdown]
# For the ODEs, we follow some of the notation from the original Beeler and Reuter paper from 1977 [$^{[2]}$](#Sources).
# The governing ODE for the membrane potential is:

# %% [markdown]
# \begin{equation}
#     C_{m}\frac{dV}{dt} = - (I_{Na} + I_{K} + I_{x} + I_{Ca}) + I_{stim},
# \end{equation}
# where
# \begin{equation}
#     I_{Na} = (g_{Na}m^{3}hj + g_{NaC})(V - V_{Na}),
# \end{equation}
# \begin{equation}
#     I_{K} = g_{K_1}\frac{\exp{(0.04(V - V_{K_1}))} - 1}{\exp{(0.08(V - V_{K_2}))} + \exp{(0.04(V - V_{K_2}))}} +
#             g_{K_2}\frac{V - V_{K_3}}{1 - \exp{(- 0.04(V - V_{K_3}))}},
# \end{equation}
# \begin{equation}
#     I_{x} = g_{x}x\frac{\exp{(0.04(V - V_{x_1}))} - 1}{\exp{(0.04(V - V_{x_2}))}},
# \end{equation}
# \begin{equation}
#     I_{Ca} = g_{Ca}fd(V - V_{Ca} + 13.0287\ln{(10^{-7}c))}.
# \end{equation}

# %% [markdown]
# During inference, the model will have the capability to infer any of the conductances, $g_{i}$ for any subscript $i$, and any of the
# Nernst (or other) potential constants, $V_{i}$. Therefore we have up to 13 parameters (6 conductances and 7 potentials) to infer. Note that
# we also fix $C_{m}$ = 1.

# %% [markdown]
# For the stimulating current, $I_{stim}$, we will allow flexibility for specifying the following parameters:

# %% [markdown]
# |parameter|description|
# |---|--------|
# |`stim_start`|The time at which the current is turned on.|
# |`stim_period`|The length of a stimulation cycle.|
# |`stim_duration`|The period for which (at the start of the stimulation cycle) the current is turned on.|
# |`stim_amplitude`|The amplitude of the current.|

# %% [markdown]
# These will be captured in a 4-membered list, and passed to the `BeelerReuterModel` below. None of these parameters will be inferred.

# %% [markdown]
# ### Gating variable and $Ca^{2+}$ ODEs

# %% [markdown]
# Below are the remaining 7 ODEs:

# %% [markdown]
# \begin{equation}
#     \frac{dy}{dt} = \alpha_{y}(1 - y) - \beta_{y}y,
# \end{equation}
# \begin{equation}
#     \frac{dc}{dt} = 0.07(1 - c) - I_{Ca},
# \end{equation}

# %% [markdown]
# where $y = m, h, j, d, f, x$ and $\alpha_{y}, \beta_{y}$ are some known functions of the membrane potential, $V$ (so we will
# not be inferring any parameters contained within these functions).

# %% [markdown]
# ### Initial conditions

# %% [markdown]
# Finally, we will assume the following initial conditions are known (using values from CellML [$^{[3]}$](#Sources)):

# %% [markdown]
# \begin{equation}
#     V(0) = -84.624, \qquad m(0) = 0.011, \qquad h(0) = 0.988, \qquad j(0) = 0.975, \qquad d(0) = 0.003, \qquad f(0) = 0.994,
#     \qquad x(0) = 0.0001, \qquad c(0) = 2.
# \end{equation}

# %% [markdown]
# The goal is to try and initially infer all 13 parameters, and then see which parameters we can restrict to improve the overall inference.

# %%
initial_conditions = [-84.624, 0.011, 0.988, 0.975, 0.003, 0.994, 0.0001, 2]

# %%
from numpy import exp, log

import pints
import numpy as np
import scipy.integrate as si
import matplotlib.pyplot as plt

# %% [markdown]
# ### PINTS implementation of the model

# %% [markdown]
# In addition to implementing the system, we give the option in the class to specify fixed parameters, if we wish to
# reduce the dimensions of the parameter space. Additionally, as we realistically would only be able to measure the membrane potential,
# $V$, and the calcium concentration, $c$, we will use these as the only outputs of the system.

# %%
class BeelerReuterModel(pints.ForwardModel):

    def __init__(self, initial_conditions, stimulating_current, fixed_params=None, outputs=["V", "c"],
                 rtol=10**(-3), atol=10**(-6)):
        """Initialises the forward model with certain fixed parameters passed to the method
        as key-value pairs.
        """
        super(BeelerReuterModel, self).__init__()
        assert len(initial_conditions) == 8
        self._initial_conditions = initial_conditions

        assert len(stimulating_current) == 4
        self._stim_start, self._stim_period, self._stim_duration, self._stim_amplitude = tuple(stimulating_current)
        self._param_names = ["g_Na", "g_NaC", "g_K1", "g_K2", "g_x", "g_Ca",
                             "V_Na", "V_K1", "V_K2", "V_K3", "V_x1", "V_x2", "V_Ca"]
        self._variable_names = ["V", "m", "h", "j", "d", "f", "x", "c"]
        self._fixed_params = {}
        if fixed_params is not None:
            for k in fixed_params.keys():
                if k in self._param_names:
                    self._fixed_params[k] = fixed_params[k]

        assert 1 <= len(outputs) <= 8
        assert set(outputs).issubset(set(self._variable_names))
        self._outputs = outputs
        self._rtol = rtol
        self._atol = atol

    def get_param_names(self):
        """Returns the parameter names.
        """
        return self._param_names

    def get_unfixed_param_names(self):
        """Returns the unfixed parameters
        """
        output_list = self._param_names.copy()
        for fixed_param in self._fixed_params.keys():
            output_list.remove(fixed_param)
        return output_list

    def n_outputs(self):
        """Returns number of model outputs, default to just V and c
        """
        return len(self._outputs)

    def n_parameters(self):
        """Returns number of parameters to be inferred, i.e. all non-fixed parameters.
        """
        return len(self._param_names) - len(self._fixed_params)

    def n_fixed_parameters(self):
        """Returns number of parameters we fix.
        """
        return len(self._fixed_params)

    def simulate(self, parameters, times):
        """This inherits from pints.ForwardModel, performs one forward simulation of the model.
        The list `parameters` contains only the parameters we are inferring.
        """
        g_Na, g_NaC, g_K1, g_K2, g_x, g_Ca, V_Na, V_K1, V_K2, V_K3, V_x1, V_x2, V_Ca = self._get_all_params(parameters)
        t_span = [times[0], times[len(times) - 1]]
        y0 = self._initial_conditions
        # sol = si.solve_ivp(fun=self._rhs, t_span=t_span, y0=y0, 
        #                    t_eval=times, args=(g_Na, g_NaC, g_K1, g_K2, g_x, g_Ca, 
        #                                        V_Na, V_K1, V_K2, V_K3, V_x1, V_x2, V_Ca,
        #                                        self._stim_start, self._stim_period, self._stim_duration, self._stim_amplitude),
        #                    rtol=self._rtol, atol=self._atol)
        sol = si.odeint(func=self._rhs, y0=y0, t=times,
                        args=(g_Na, g_NaC, g_K1, g_K2, g_x, g_Ca, 
                              V_Na, V_K1, V_K2, V_K3, V_x1, V_x2, V_Ca,
                              self._stim_start, self._stim_period, self._stim_duration, self._stim_amplitude),
                        rtol=self._rtol, atol=self._atol)

        # Now we find which outputs we wish to use
        output_indices = [self._variable_names.index(variable) for variable in self._outputs]
        return np.array([sol[:, index] for index in output_indices]).transpose()

    def _get_all_params(self, parameters):
        """We need a list of 13 parameters, so we check to see which parameters are fixed, and which are not.
        We increment j each time a non-fixed parameter is reached.
        """
        all_parameters = []
        j = 0
        for param in self._param_names:
            if param in self._fixed_params.keys():
                all_parameters.append(self._fixed_params[param])
            else:
                all_parameters.append(parameters[j])
                j += 1
        return tuple(all_parameters)

    @staticmethod
    def _rhs(y, t, g_Na, g_NaC, g_K1, g_K2, g_x, g_Ca, 
             V_Na, V_K1, V_K2, V_K3, V_x1, V_x2, V_Ca,
             stim_start, stim_period, stim_duration, stim_amplitude):
        """The right hand side function of the Beeler-Reuter system.
        """
        # Variables
        V, m, h, j, d, f, x, c = tuple(list(y))

        # Currents
        I_Na = (g_Na * (m**3) * h * j + g_NaC) * (V - V_Na)
        I_K = g_K1 * (exp(0.04 * (V - V_K1)) - 1) / (exp(0.08 * (V - V_K2)) + exp(0.04 * (V - V_K2))) + g_K2 * (V - V_K3) / (1 - exp(-0.04 * (V - V_K3)))
        I_x = g_x * x * (exp(0.04 * (V - V_x1)) - 1) / exp(0.04 * (V - V_x2))
        I_Ca = g_Ca * d * f * (V - V_Ca + 13.0287 * (log(c) - 7 * log(10)))

        # Stimulation parameters
        if (t - stim_start) % stim_period <= stim_duration:
            I_stim = stim_amplitude
        else:
            I_stim = 0

        # Membrane potential ODE
        V_dot = - (I_Na + I_K + I_x + I_Ca) + I_stim

        # Gating variable ODEs
        m_dot = (V + 47) / (1 - exp(-0.1 * (V + 47))) * (1 - m) - 40 * exp(-0.056 * (V + 72)) * m
        h_dot = 0.126 * exp(-0.25 * (V + 77)) * (1 - h) - 1.7 / (1 + exp(-0.082 * (V + 22.5))) * h
        j_dot = 0.055 * exp(-0.25 * (V + 78)) / (1 + exp(-0.2 * (V + 78))) * (1 - j) - 0.3 / (1 + exp(-0.1 * (V + 32))) * j
        d_dot = 0.095 * exp(-0.01 * (V + -5)) / (exp(-0.072 * (V + -5)) + 1) * (1 - d) - 0.07 * exp(-0.017 * (V + 44)) / (exp(0.05 * (V + 44)) + 1) * d
        f_dot = 0.012 * exp(-0.008 * (V + 28)) / (exp(0.15 * (V + 28)) + 1) * (1 - f) - 0.0065 * exp(-0.02 * (V + 30)) / (exp(-0.2 * (V + 30)) + 1) * f
        x_dot = 0.0005 * exp(0.083 * (V + 50)) / (exp(0.057 * (V + 50)) + 1) * (1 - x) - 0.0013 * exp(-0.06 * (V + 20)) / (exp(-0.04 * (V + 20)) + 1) * x

        # Calcium concentration ODE
        c_dot = 0.07 * (1 - c) - I_Ca
        return np.array([V_dot, m_dot, h_dot, j_dot, d_dot, f_dot, x_dot, c_dot])

# %% [markdown]
# ## Generating data for the model

# %% [markdown]
# ### Simulating the system

# %% [markdown]
# Next, we will generate some data for the model using known parameter values. We use the ones chosen by Keener and Sneyd (pg 150) [$^{[1]}$](#Sources), tabulated below:

# %% [markdown]
# |parameter|value|
# |-----|-----|
# |$g_{Na}$|4|
# |$g_{NaC}$|0.003|
# |$g_{K_1}$|1.4|
# |$g_{K_2}$|0.07|
# |$g_{x}$|0.8|
# |$g_{Ca}$|0.09|
# |$V_{Na}$|50|
# |$V_{K_1}$|-85|
# |$V_{K_2}$|-53|
# |$V_{K_3}$|-23|
# |$V_{x_1}$|-77|
# |$V_{x_2}$|-35|
# |$V_{Ca}$|-82.3|

# %% [markdown]
# The below stimulation parameters are related to ones chosen in CellML [$^{[3]}$](#Sources).

# %% [markdown]
# Conductances: $g_{Na},$ $g_{NaC},$ $g_{K_1},$ $g_{K_2},$ $g_{x},$ $g_{Ca}$
#
# Nernst potentials and other potential constants: $V_{Na},$ $V_{K_1},$ $V_{K_2},$ $V_{K_3},$ $V_{x_1},$ $V_{x_2},$ $V_{Ca}$

# %%
# Here we choose whether to fix the potentials or not
# fixed_params = {"V_Na": 50, "V_K1": -85, "V_K2": -53, "V_K3": -23, "V_x1": -77, "V_x2": -35, "V_Ca": -82.3}
fixed_params = None
# Stimulation parameters [stim_start, stim_period, stim_duration, stim_amplitude]
stim_params = [1, 1000, 2, 25]

# %%
model = BeelerReuterModel(initial_conditions, stim_params, fixed_params=fixed_params, outputs=["V"], rtol=10**(-8), atol=10**(-8))
param_names = model.get_unfixed_param_names()
print(param_names)
# parameters = np.array([4, 0.003, 1.4, 0.07, 0.8, 0.09])
parameters = np.array([4, 0.003, 1.4, 0.07, 0.8, 0.09, 50, -85, -53, -23, -77, -35, -82.3])
times = np.arange(0, 400, 1)
# Out:
# ['g_Na', 'g_NaC', 'g_K1', 'g_K2', 'g_x', 'g_Ca', 'V_Na', 'V_K1', 'V_K2', 'V_K3', 'V_x1', 'V_x2', 'V_Ca']

# %%
data = model.simulate(parameters, times)

# %%
import pandas as pd

# %%
output_param_df = pd.DataFrame({"true": parameters})

# %% [markdown]
# ### Adding noise to the system

# %% [markdown]
# We now utilise PINTS noise generators to create some noisy data for the system. Specifically, `pints.noise.independent`
# creates independent Gaussian noise iid $\mathcal{N}(0, \sigma)$.

# %%
sigma = 1
noisy_data = data + pints.noise.independent(sigma, data.shape)

# %% [markdown]
# ### Plotting time series and phase plane

# %%
import matplotlib.pyplot as plt

# %%
noisy_df = pd.DataFrame(noisy_data, columns=["V"])
noisy_df.to_csv("simulation_outputs/noisy_data_tol.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 noisy_df = pd.DataFrame(noisy_data, columns=["V"])
#       2 noisy_df.to_csv("simulation_outputs/noisy_data_tol.csv")
#
# NameError: name 'noisy_data' is not defined

# %%
noisy_data = pd.read_csv("simulation_outputs/noisy_data_tol.csv", index_col=0).to_numpy()
noisy_V = noisy_data[:, 0]
# V, c = data[:, 0], data[:, 1]

# %%
V = data[:, 0]
# noisy_V, noisy_c = noisy_data[:, 0], noisy_data[:, 1]
plt.plot(times, V, "-r", label="Without noise")
plt.plot(times, noisy_V, "-b", alpha=0.5, label="With noise")
plt.xlabel("Time [ms]")
plt.ylabel("Potential [mV]")
plt.legend()
plt.title("Membrane potential")
plt.savefig("simulation_outputs/time_series_tol.png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 4
#       2 # noisy_V, noisy_c = noisy_data[:, 0], noisy_data[:, 1]
#       3 plt.plot(times, V, "-r", label="Without noise")
# ----> 4 plt.plot(times, noisy_V, "-b", alpha=0.5, label="With noise")
#       5 plt.xlabel("Time [ms]")
#       6 plt.ylabel("Potential [mV]")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (400,) and (100,)

# %%
plt.plot(times, c, label="Without noise")
plt.plot(times, noisy_c, label="With noise")
plt.xlabel("Time [ms]")
plt.ylabel("Concentration [1e-7 mol/L]")
plt.legend()
plt.title("Ca2+ concentration")
plt.savefig("simulation_outputs/time_series_c.png")

# %% [markdown]
# ## Using PINTS to perform inference

# %% [markdown]
# We will now perform Bayesian inference on the model to try and recover the values of the input parameters. Here, we use the CMAES-ACMC
# combination by optimising the problem first to find starting parameters with CMAES and then using ACMC to perform Bayesian inference
# on the parameters.

# %% [markdown]
# ### Optimisation using `pints.CMAES`

# %% [markdown]
# We first use the optimiser to reach some realistic parameter values for the noisy data.

# %%
problem = pints.MultiOutputProblem(model, times, noisy_data)
score = pints.SumOfSquaresError(problem)

# %% [markdown]
# Next, choose some boundaries for the parameters. We know the signs of the Nernst potentials, as K$^{+}$ flows out of the cell
# and Na$^{+}$, Ca$^{2+}$ flow into the cell. For the conductances, we assume that we can know their order of magnitude.

# %%
# boundaries = pints.RectangularBoundaries([0, 0, 0, 0, 0, 0],
#                                         [10, 0.1, 10, 1, 1, 1])
boundaries = pints.RectangularBoundaries([0, 0, 0, 0, 0, 0, 20, -100, -100, -100, -100, -100, -100],
                                        [10, 0.1, 10, 1, 1, 1, 100, -20, -20, -20, -20, -20, -20])
log_prior = pints.UniformLogPrior(boundaries)
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_22176\3026651079.py:5: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   log_prior = pints.UniformLogPrior(boundaries)

# %%
num_opts = 10

# %% [markdown]
# And here we perform the optimisation. We choose to run this `num_opts` times to try and find the optimal solution of the different
# optimised parameters. Each optimisation is deemed complete if the objective function has not changed by more than $10^{-8}$ over a
# period of $200$ iterations. We save the parameters from each optimisation to a .csv file.

# %%
for j in range(6, num_opts):
    xs = log_prior.sample(1)
    # sigma = [0.1, 0.001, 0.1, 0.01, 0.01, 0.01, 1, 1, 1, 1, 1, 1, 1]
    # transform = pints.RectangularBoundariesTransformation(boundaries)
    opt = pints.OptimisationController(score, xs, boundaries=boundaries, method=pints.CMAES)
    opt.set_max_unchanged_iterations(200, 0.00000001)
    opt.set_max_iterations(1000)
    opt_params, opt_values = opt.run()
    opt_param_df = pd.DataFrame({param_names[i]: [opt_params[i]] for i in range(model.n_parameters())})
    opt_param_df.to_csv(f"optimisation_outputs/parameters_tol_all/opt_params_{j}.csv")
# Out:
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 11
# Iter. Eval.  Best      Current   Time m:s
# 0     11      352139.7  352139.7   0:43.3
# 1     22      341032.4  341032.4   1:14.8
# 2     33      322701.8  322701.8   1:39.4
# 3     44      302368.8  302368.8   1:57.7
# 20    231     103384.3  103384.3   5:44.2
# 40    451     45296.19  51988.4   12:19.8
# 60    671     27138.33  38344.33  20:35.1
# 80    891     14390.89  16794.71  27:38.8
# 100   1111    7478.884  7478.884  34:19.4
# 120   1331    6432.438  7226.566  40:05.4
# 140   1551    6342.432  6373.917  45:55.5
# 160   1771    6341.347  6346.38   51:41.0
# 180   1991    6332.823  6333.15   57:20.5
# 200   2211    6313.451  6313.451  63:17.4
# 220   2431    6190.847  6190.847  69:03.5
# 240   2651    6148.706  6158.966  74:48.7
# 260   2871    6132.724  6132.724  80:29.8
# 280   3091    6052.974  6052.974  86:08.0
# 300   3311    5873.829  5873.829  91:46.5
# 320   3531    5248.769  5248.769  97:17.2
# 340   3751    3243.307  3243.307 102:49.5
# 360   3971    2500.302  2579.149 108:26.6
# 380   4191    2189.09   2189.09  114:22.0
# 400   4411    1819.093  1940.455 120:27.6
# 420   4631    961.7072  1260.815 126:27.1
# 440   4851    471.9946  532.7879 132:55.9
# 460   5071    366.1028  407.3642 140:07.2
# 480   5291    291.7284  291.7284 147:02.0
# 500   5511    277.6145  277.6477 153:43.2
# 520   5731    274.1719  274.3886 160:23.7
# 540   5951    273.1379  273.1379 167:04.9
# 560   6171    272.5899  272.5965 173:45.4
# 580   6391    270.5616  270.5616 180:32.8
# 600   6611    266.3726  266.618  187:14.0
# 620   6831    246.7821  246.7821 193:52.7
# 640   7051    221.5049  221.5049 200:35.4
# 660   7271    189.2192  192.7951 207:27.4
# 680   7491    174.5364  177.5163 214:49.9
# 700   7711    170.717   171.8144 222:38.8
# 720   7931    164.1503  165.3812 230:03.1
# 740   8151    159.5367  159.7988 237:57.3
# 760   8371    153.3512  153.7923 246:15.2
# 780   8591    147.9836  147.9836 253:40.0
# 800   8811    140.8999  141.7754 261:18.1
# 820   9031    133.5165  135.4975 268:47.7
# 840   9251    129.1193  129.1193 276:05.3
# 860   9471    121.7749  121.7749 284:06.4
# 880   9691    113.7973  114.8537 292:08.2
# 900   9911    109.0765  109.0909 300:01.4
# 920   10131   105.2682  105.2682 307:20.0
# 940   10351   102.6176  103.0526 314:35.0
# 960   10571   101.7906  101.7906 321:46.4
# 980   10791   99.02471  99.28235 329:03.2
# 1000  11000   94.9255   96.75353 335:56.6
# Halting: Maximum number of iterations (1000) reached.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running
# 180   1991    12808.72  12808.72  50:53.9
# 200   2211    12741.84  12741.84  56:08.6
# 220   2431    12598.97  12598.97  61:27.8
# 240   2651    12520.48  12546.55  66:46.2
# 260   2871    12453.52  12468.54  72:08.8
# 280   3091    12113.66  12145.58  77:29.3
# 300   3311    11673.98  11687.41  83:00.2
# 320   3531    11305.38  11305.38  88:31.9
# 340   3751    10965.83  11018.82  94:02.7
# 360   3971    9886.842  9886.842  99:42.7
# 380   4191    7750.337  7750.337 105:41.2
# 400   4411    3586.319  5296.545 111:47.9
# 420   4631    2649.951  2653.47  117:37.5
# 440   4851    1902.795  2125.774 123:37.8
# 460   5071    1159.176  1159.176 129:33.6
# 480   5291    681.6097  707.129  135:51.0
# 500   5511    639.195   662.2911 142:20.9
# 520   5731    471.2571  492.0907 148:43.1
# 540   5951    471.2571  490.132  155:08.4
# 560   6171    457.648   458.3623 161:32.8
# 580   6391    447.8892  447.8892 167:56.0
# 600   6611    442.5555  443.1027 174:21.3
# 620   6831    434.91    434.91   180:48.1
# 640   7051    424.8281  424.8281 187:13.3
# 660   7271    402.2116  402.2116 193:37.8
# 680   7491    383.718   386.1968 200:03.7
# 700   7711    348.4019  353.4186 206:31.4
# 720   7931    327.1012  327.1012 212:57.1
# 740   8151    283.6086  287.8136 219:24.7
# 760   8371    257.7306  257.7306 225:50.0
# 780   8591    207.4697  217.5446 232:24.4
# 800   8811    160.485   161.7124 238:51.5
# 820   9031    112.0372  112.0372 245:22.1
# 840   9251    102.6439  102.6439 251:47.9
# 860   9471    97.84013  97.94357 258:18.7
# 880   9691    97.50147  97.50147 264:46.7
# 900   9911    96.41212  96.41212 271:13.4
# 920   10131   95.01175  95.18062 277:37.1
# 940   10351   94.44772  94.44772 284:05.7
# 960   10571   94.22057  94.25085 290:42.6
# 980   10791   94.03951  94.03951 297:10.5
# 1000  11000   93.78907  93.78907 303:19.1
# Halting: Maximum number of iterations (1000) reached.

# %% [markdown]
# If the optimisation has not converged, but has a sufficiently low score, we will take the parameters at this stage.

# %%
opt_params = opt.optimiser().x_best()
# opt_params = (boundaries.lower() + boundaries.upper()*exp(transformed_opt_params))/(1 + exp(transformed_opt_params))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 opt_params = opt.optimiser().x_best()
#       2 # opt_params = (boundaries.lower() + boundaries.upper()*exp(transformed_opt_params))/(1 + exp(transformed_opt_params))
#
# NameError: name 'opt' is not defined

# %% [markdown]
# Save these parameters to a .csv file and then read from the file afterwards.

# %%
import pandas as pd

# %%
opt_param_df = pd.DataFrame({param_names[i]: [opt_params[i]] for i in range(model.n_parameters())})
opt_param_df.to_csv(f"optimisation_outputs/parameters_tol_all/opt_params_{0}.csv")

# %% [markdown]
# ### Plotting with optimised parameters

# %%
opt_params = []
num_opts = 10
for j in range(num_opts):
    opt_param_df = pd.read_csv(f"optimisation_outputs/parameters_tol_all/opt_params_{j}.csv", index_col=0)
    opt_params.append(opt_param_df.to_numpy()[0])

# %%
errors = []
true_error = score(parameters)
print("---------------------------------------------------------------------------")
print(f"True parameters, sum of squared errors = {round(true_error, 5)}")
for j in range(num_opts):
    print("---------------------------------------------------------------------------")
    error = score(opt_params[j])
    print(f"Optimisation {j}, sum of squared errors = {round(error, 5)}")
    print("---------------------------------------------------------------------------")
    errors.append(error)
    output_list = []
    for i in range(model.n_parameters()):
        opt_param = round(opt_params[j][i], 5)
        output_list.append(opt_param)
        print(f"Parameter: {param_names[i]}, True: {parameters[i]}, Optimised: {opt_param}")
    output_param_df[f"Optimisation {j}"] = output_list
# Out:
# ---------------------------------------------------------------------------
# True parameters, sum of squared errors = 95.77575
# ---------------------------------------------------------------------------
# Optimisation 0, sum of squared errors = 85.76086
# ---------------------------------------------------------------------------
# Parameter: g_Na, True: 4.0, Optimised: 4.24513
# Parameter: g_NaC, True: 0.003, Optimised: 0.00286
# Parameter: g_K1, True: 1.4, Optimised: 0.52701
# Parameter: g_K2, True: 0.07, Optimised: 0.06741
# Parameter: g_x, True: 0.8, Optimised: 0.58245
# Parameter: g_Ca, True: 0.09, Optimised: 0.11674
# Parameter: V_Na, True: 50.0, Optimised: 48.51406
# Parameter: V_K1, True: -85.0, Optimised: -82.95372
# Parameter: V_K2, True: -53.0, Optimised: -31.36675
# Parameter: V_K3, True: -23.0, Optimised: -27.95729
# Parameter: V_x1, True: -77.0, Optimised: -81.87985
# Parameter: V_x2, True: -35.0, Optimised: -32.85664
# Parameter: V_Ca, True: -82.3, Optimised: -91.01215
# ---------------------------------------------------------------------------
# Optimisation 1, sum of squared errors = 88.26763
# ---------------------------------------------------------------------------
# Parameter: g_Na, True: 4.0, Optimised: 2.64872
# Parameter: g_NaC, True: 0.003, Optimised: 0.00338
# Parameter: g_K1, True: 1.4, Optimised: 0.81883
# Parameter: g_K2, True: 0.07, Optimised: 0.06329
# Parameter: g_x, True: 0.8, Optimised: 0.57915
# Parameter: g_Ca, True: 0.09, Optimised: 0.09162
# Parameter: V_Na, True: 50.0, Optimised: 67.28217
# Parameter: V_K1, True: -85.0, Optimised: -82.96663
# Parameter: V_K2, True: -53.0, Optimised: -42.17436
# Parameter: V_K3, True: -23.0, Optimised: -31.61894
# Parameter: V_x1, True: -77.0, Optimised: -84.07261
# Parameter: V_x2, True: -35.0, Optimised: -36.67146
# Parameter: V_Ca, True: -82.3, Optimised: -82.74492
# ---------------------------------------------------------------------------
# Optimisation 2, sum of squared errors = 99.3363
# ---------------------------------------------------------------------------
# Parameter: g_Na, True: 4.0, Optimised: 4.16253
# Parameter: g_NaC, True: 0.003, Optimised: 0.00422
# Parameter: g_K1, True: 1.4, Optimised: 2.37238
# Parameter: g_K2, True: 0.07, Optimised: 0.04364
# Parameter: g_x, True: 0.8, Optimised: 0.47938
# Parameter: g_Ca, True: 0.09, Optimised: 0.05563
# Parameter: V_Na, True: 50.0, Optimised: 46.12175
# Parameter: V_K1, True: -85.0, Optimised: -81.0001
# Parameter: V_K2, True: -53.0, Optimised: -63.21871
# Parameter: V_K3, True: -23.0, Optimised: -45.18632
# Parameter: V_x1, True: -77.0, Optimised: -96.84233
# Parameter: V_x2, True: -35.0, Optimised: -52.74056
# Parameter: V_Ca, True: -82.3, Optimised: -68.1871
# ---------------------------------------------------------------------------
# Optimisation 3, sum of squared errors = 89.34847
# ---------------------------------------------------------------------------
# Parameter: g_Na, True: 4.0, Optimised: 4.11815
# Parameter: g_NaC, True: 0.003, Optimised: 1e-05
# Parameter: g_K1, True: 1.4, Optimised: 1.13707
# Parameter: g_K2, True: 0.07, Optimised: 0.06541
# Parameter: g_x, True: 0.8, Optimised: 0.91427
# Parameter: g_Ca, True: 0.09, Optimised: 0.10569
# Parameter: V_Na, True: 50.0, Optimised: 49.44509
# Parameter: V_K1, True: -85.0, Optimised: -82.45526
# Parameter: V_K2, True: -53.0, Optimised: -47.9843
# Parameter: V_K3, True: -23.0, Optimised: -30.14633
# Parameter: V_x1, True: -77.0, Optimised: -75.79063
# Parameter: V_x2, True: -35.0, Optimised: -36.9455
# Parameter: V_Ca, True: -82.3, Optimised: -87.06743
# ---------------------------------------------------------------------------
# Optimisation 4, sum of squared errors = 105.72667
# ---------------------------------------------------------------------------
# Parameter: g_Na, True: 4.0, Optimised: 1.84738
# Parameter: g_NaC, True: 0.003, Optimised: 0.00835
# Parameter: g_K1, True: 1.4, Optimised: 3.55941
# Parameter: g_K2, True: 0.07, Optimised: 0.04201
# Parameter: g_x, True: 0.8, Optimised: 0.40742
# Parameter: g_Ca, True: 0.09, Optimised: 0.06636
# Parameter: V_Na, True: 50.0, Optimised: 92.63629
# Parameter: V_K1, True: -85.0, Optimised: -88.91353
# Parameter: V_K2, True: -53.0, Optimised: -69.6773
# Parameter: V_K3, True: -23.0, Optimised: -73.84998
# Parameter: V_x1, True: -77.0, Optimised: -72.79969
# Parameter: V_x2, True: -35.0, Optimised: -20.09319
# Parameter: V_Ca, True: -82.3, Optimised: -67.3259
# ---------------------------------------------------------------------------
# Optimisation 5, sum of squared errors = 109.42001
# ---------------------------------------------------------------------------
# Parameter: g_Na, True: 4.0, Optimised: 2.90033
# Parameter: g_NaC, True: 0.003, Optimised: 0.01801
# Parameter: g_K1, True: 1.4, Optimised: 2.76145
# Parameter: g_K2, True: 0.07, Optimised: 0.03545
# Parameter: g_x, True: 0.8, Optimised: 0.98835
# Parameter: g_Ca, True: 0.09, Optimised: 0.03909
# Parameter: V_Na, True: 50.0, Optimised: 60.19145
# Parameter: V_K1, True: -85.0, Optimised: -94.5917
# Parameter: V_K2, True: -53.0, Optimised: -66.8168
# Parameter: V_K3, True: -23.0, Optimised: -75.37465
# Parameter: V_x1, True: -77.0, Optimised: -75.82436
# Parameter: V_x2, True: -35.0, Optimised: -49.16637
# Parameter: V_Ca, True: -82.3, Optimised: -41.52821
# ---------------------------------------------------------------------------
# Optimisation 6, sum of squared errors = 94.9255
# ---------------------------------------------------------------------------
# Parameter: g_Na, True: 4.0, Optimised: 9.06609
# Parameter: g_NaC, True: 0.003, Optimised: 0.01352
# Parameter: g_K1, True: 1.4, Optimised: 0.86124
# Parameter: g_K2, True: 0.07, Optimised: 0.02525
# Parameter: g_x, True: 0.8, Optimised: 0.94901
# Parameter: g_Ca, True: 0.09, Optimised: 0.06597
# Parameter: V_Na, True: 50.0, Optimised: 33.3117
# Parameter: V_K1, True: -85.0, Optimised: -86.821
# Parameter: V_K2, True: -53.0, Optimised: -46.27129
# Parameter: V_K3, True: -23.0, Optimised: -94.28292
# Parameter: V_x1, True: -77.0, Optimised: -98.00264
# Parameter: V_x2, True: -35.0, Optimised: -74.17536
# Parameter: V_Ca, True: -82.3, Optimised: -83.58679
# ---------------------------------------------------------------------------
# Optimisation 7, sum of squared errors = 93.6269
# ---------------------------------------------------------------------------
# Parameter: g_Na, True: 4.0, Optimised: 7.85341
# Parameter: g_NaC, True: 0.003, Optimised: 0.00169
# Parameter: g_K1, True: 1.4, Optimised: 2.86008
# Parameter: g_K2, True: 0.07, Optimised: 0.0275
# Parameter: g_x, True: 0.8, Optimised: 0.99975
# Parameter: g_Ca, True: 0.09, Optimised: 0.076
# Parameter: V_Na, True: 50.0, Optimised: 35.33959
# Parameter: V_K1, True: -85.0, Optimised: -74.76287
# Parameter: V_K2, True: -53.0, Optimised: -66.28675
# Parameter: V_K3, True: -23.0, Optimised: -96.76946
# Parameter: V_x1, True: -77.0, Optimised: -99.00279
# Parameter: V_x2, True: -35.0, Optimised: -75.17483
# Parameter: V_Ca, True: -82.3, Optimised: -84.05465
# ---------------------------------------------------------------------------
# Optimisation 8, sum of squared errors = 88.97255
# ---------------------------------------------------------------------------
# Parameter: g_Na, True: 4.0, Optimised: 4.01347
# Parameter: g_NaC, True: 0.003, Optimised: 0.02197
# Parameter: g_K1, True: 1.4, Optimised: 0.63962
# Parameter: g_K2, True: 0.07, Optimised: 0.04842
# Parameter: g_x, True: 0.8, Optimised: 0.99304
# Parameter: g_Ca, True: 0.09, Optimised: 0.08414
# Parameter: V_Na, True: 50.0, Optimised: 49.47885
# Parameter: V_K1, True: -85.0, Optimised: -99.66941
# Parameter: V_K2, True: -53.0, Optimised: -41.9402
# Parameter: V_K3, True: -23.0, Optimised: -56.52661
# Parameter: V_x1, True: -77.0, Optimised: -75.56396
# Parameter: V_x2, True: -35.0, Optimised: -40.32223
# Parameter: V_Ca, True: -82.3, Optimised: -80.29795
# ---------------------------------------------------------------------------
# Optimisation 9, sum of squared errors = 93.78907
# ---------------------------------------------------------------------------
# Parameter: g_Na, True: 4.0, Optimised: 4.51201
# Parameter: g_NaC, True: 0.003, Optimised: 0.00199
# Parameter: g_K1, True: 1.4, Optimised: 2.99151
# Parameter: g_K2, True: 0.07, Optimised: 0.02919
# Parameter: g_x, True: 0.8, Optimised: 0.47853
# Parameter: g_Ca, True: 0.09, Optimised: 0.0849
# Parameter: V_Na, True: 50.0, Optimised: 44.83747
# Parameter: V_K1, True: -85.0, Optimised: -75.22635
# Parameter: V_K2, True: -53.0, Optimised: -66.47857
# Parameter: V_K3, True: -23.0, Optimised: -99.41603
# Parameter: V_x1, True: -77.0, Optimised: -93.45476
# Parameter: V_x2, True: -35.0, Optimised: -48.46575
# Parameter: V_Ca, True: -82.3, Optimised: -84.81056

# %%
chosen_opt = 0

# %%
opt_soln = model.simulate(opt_params[chosen_opt], times)
# opt_V, opt_c = opt_soln[:, 0], opt_soln[:, 1]
opt_V = opt_soln[:, 0]
plt.plot(times, opt_V, "-r", label="Optimised")
plt.plot(times, noisy_V, "-b", alpha=0.5, label="True data")
plt.xlabel("Time [ms]")
plt.ylabel("Potential [mV]")
plt.legend()
plt.title(f"Membrane potential for optimisation {chosen_opt}")
plt.savefig(f"optimisation_outputs/time_series_tol_all_{chosen_opt}.png")

# %%
plt.plot(times, opt_c, label="Optimised")
plt.plot(times, noisy_c, label="True data")
plt.xlabel("Time [ms]")
plt.ylabel("Concentration [1e-7 mol/L]")
plt.legend()
plt.title("Ca2+ concentration")
plt.savefig(f"optimisation_outputs/time_series_c_{chosen_opt}.png")

# %% [markdown]
# ### Inference using `pints.HaarioBardenetACMC`

# %%
log_likelihood = pints.GaussianLogLikelihood(problem)
composed_log_prior = pints.ComposedLogPrior(log_prior,
                                            pints.TruncatedGaussianLogPrior(0, 1, 0, np.inf),
                                            # pints.TruncatedGaussianLogPrior(0, 1, 0, np.inf)
                                           )
log_posterior = pints.LogPosterior(log_likelihood, composed_log_prior)

# %% [markdown]
# ### Initialising chains

# %% [markdown]
# Here, we initialise the chain with the optimised parameters. We only need one chain for our purpose as we use
# parameters close to the true value.

# %%
# xs = np.tile(np.array(opt_params[chosen_opt].tolist() + [1] + [1]), (1, 1))
xs = np.tile(np.array(opt_params[chosen_opt].tolist() + [1]), (1, 1))
num_chains = 1
# transform = pints.RectangularBoundariesTransformation([0, 0, 0, 0, 0, 0, 0, 0],
#                                         [10, 1, 10, 1, 1, 1, 10, 10])
# transform = pints.RectangularBoundariesTransformation([0, 0, 0, 0, 0, 0, 0],
#                                         [10, 1, 10, 1, 1, 1, 10])
transform = pints.RectangularBoundariesTransformation([0, 0, 0, 0, 0, 0, 20, -100, -100, -100, -100, -100, -100, 0],
                                        [10, 1, 10, 1, 1, 1, 100, -20, -20, -20, -20, -20, -20, 10])

# %% [markdown]
# ### Performing inference

# %%
n_params = log_prior.n_parameters()
mcmc = pints.MCMCController(log_posterior, num_chains, xs, method=pints.HaarioBardenetACMC, transformation=transform)
max_iterations = 100000
mcmc.set_max_iterations(max_iterations)
# mcmc.set_parallel(True)
# print(mcmc.parallel())

chains = mcmc.run()
# Out:
# Using Haario-Bardenet adaptive covariance MCMC
# Generating 1 chains.
# Running in sequential mode.
# Iter. Eval. Accept.   Time m:s
# 0     1      0          0:00.1
# 1     2      0          0:00.2
# 2     3      0          0:00.3
# 3     4      0          0:00.4
# 20    21     0          0:02.6
# 40    41     0          0:04.8
# 60    61     0          0:06.5
# 80    81     0          0:08.2
# 100   101    0          0:09.9
# 120   121    0          0:11.7
# 140   141    0          0:13.4
# 160   161    0          0:15.1
# 180   181    0          0:16.7
# Initial phase completed.
# 200   201    0          0:18.3
# 220   221    0.00452    0:20.0
# 240   241    0.0373     0:21.7
# 260   261    0.0805     0:23.3
# 280   281    0.103      0:25.0
# 300   301    0.126      0:26.6
# 320   321    0.14       0:28.2
# 340   341    0.15       0:29.8
# 360   361    0.166205   0:31.4
# 380   381    0.175853   0:32.9
# 400   401    0.177      0:34.5
# 420   421    0.183      0:36.1
# 440   441    0.188      0:37.8
# 460   461    0.197397   0:39.4
# 480   481    0.198      0:41.0
# 500   501    0.2        0:42.7
# 520   521    0.202      0:44.3
# 540   541    0.205      0:46.0
# 560   561    0.21       0:47.6
# 580   581    0.21       0:49.3
# 600   601    0.21       0:50.9
# 620   621    0.206      0:52.5
# 640   641    0.207      0:54.1
# 660   661    0.207      0:55.8
# 680   681    0.204      0:57.5
# 700   701    0.203      0:59.1
# 720   721    0.204      1:00.7
# 740   741    0.204      1:02.3
# 760   761    0.202      1:04.0
# 780   781    0.202      1:05.6
# 800   801    0.202      1:07.5
# 29960 29961  0.220253  46:13.1
# 29980 29981  0.22      46:15.0
# 30000 30001  0.220126  46:16.8
# 30020 30021  0.22      46:18.6
# 30040 30041  0.22      46:20.5
# 30060 30061  0.22      46:22.3
# 30080 30081  0.22      46:25.1
# 30100 30101  0.22      46:27.3
# 30120 30121  0.22      46:29.1
# 30140 30141  0.22      46:31.0
# 30160 30161  0.22      46:32.7
# 30180 30181  0.22      46:34.7
# 30200 30201  0.221     46:36.5
# 30220 30221  0.220542  46:38.4
# 30240 30241  0.221     46:40.2
# 30260 30261  0.220647  46:42.0
# 30280 30281  0.221     46:43.9
# 30300 30301  0.221     46:45.7
# 30320 30321  0.220903  46:47.4
# 30340 30341  0.221     46:49.2
# 30360 30361  0.221     46:51.2
# 30380 30381  0.221     46:53.2
# 30400 30401  0.221     46:55.1
# 30420 30421  0.221     46:56.9
# 30440 30441  0.221     46:58.7
# 30460 30461  0.221     47:00.6
# 30480 30481  0.221     47:02.4
# 30500 30501  0.221     47:04.2
# 30520 30521  0.220635  47:06.0
# 30540 30541  0.221     47:07.8
# 30560 30561  0.221     47:09.6
# 30580 30581  0.22      47:11.4
# 30600 30601  0.22      47:13.4
# 30620 30621  0.22      47:15.2
# 30640 30641  0.22      47:17.1
# 30660 30661  0.22      47:18.8
# 30680 30681  0.22      47:20.7
# 30700 30701  0.22      47:22.5
# 30720 30721  0.22      47:24.4
# 30740 30741  0.22      47:26.3
# 30760 30761  0.22      47:28.2
# 30780 30781  0.22      47:30.1
# ...
# 89740 89741  0.223    139:52.9
# 89760 89761  0.223    139:54.8
# 89780 89781  0.223    139:56.6
# 89800 89801  0.223    139:58.4
# 89820 89821  0.223    140:00.2
# 89840 89841  0.223    140:02.0
# 89860 89861  0.224    140:03.9
# 89880 89881  0.224    140:05.7
# 89900 89901  0.224    140:08.7
# 89920 89921  0.224    140:10.5
# 89940 89941  0.224    140:12.3
# 89960 89961  0.224    140:14.2
# 89980 89981  0.224    140:16.0
# 90000 90001  0.224    140:17.8
# 90020 90021  0.224    140:19.6
# 90040 90041  0.224    140:21.4
# 90060 90061  0.224    140:23.3
# 90080 90081  0.224    140:25.2
# 90100 90101  0.224    140:27.0
# 90120 90121  0.224    140:28.8
# 90140 90141  0.224    140:30.7
# 90160 90161  0.224    140:32.5
# 90180 90181  0.224    140:34.4
# 90200 90201  0.224    140:36.2
# 90220 90221  0.223673 140:38.1
# 90240 90241  0.224    140:39.9
# 90260 90261  0.224    140:41.8
# 90280 90281  0.224    140:43.8
# 90300 90301  0.223807 140:45.8
# 90320 90321  0.224    140:47.6
# 90340 90341  0.224    140:49.5
# 90360 90361  0.224    140:51.3
# 90380 90381  0.224    140:53.1
# 90400 90401  0.224    140:54.9
# 90420 90421  0.224    140:56.8
# 90440 90441  0.224    140:58.6
# 90460 90461  0.224    141:00.5
# 90480 90481  0.224    141:02.3
# 90500 90501  0.224    141:04.2
# 90520 90521  0.224    141:06.0
# 90540 90541  0.224    141:07.8
# 90560 90561  0.224    141:09.7
# 90580 90581  0.224    141:11.5
# 97460 97461  0.225    152:08.4
# 97480 97481  0.225    152:10.2
# 97500 97501  0.225    152:12.1
# 97520 97521  0.225    152:14.1
# 97540 97541  0.225    152:15.8
# 97560 97561  0.225    152:17.7
# 97580 97581  0.225    152:19.5
# 97600 97601  0.225    152:21.4
# 97620 97621  0.225    152:23.2
# 97640 97641  0.225    152:25.0
# 97660 97661  0.224624 152:26.9
# 97680 97681  0.225    152:28.8
# 97700 97701  0.225    152:30.7
# 97720 97721  0.225    152:32.6
# 97740 97741  0.225    152:34.5
# 97760 97761  0.225    152:36.4
# 97780 97781  0.225    152:38.2
# 97800 97801  0.225    152:40.1
# 97820 97821  0.225    152:42.0
# 97840 97841  0.225    152:44.3
# 97860 97861  0.225    152:46.1
# 97880 97881  0.225    152:48.0
# 97900 97901  0.225    152:49.8
# 97920 97921  0.225    152:51.7
# 97940 97941  0.225    152:53.5
# 97960 97961  0.225    152:55.3
# 97980 97981  0.225    152:57.2
# 98000 98001  0.224    152:59.0
# 98020 98021  0.224    153:00.9
# 98040 98041  0.225    153:02.7
# 98060 98061  0.225    153:04.6
# 98080 98081  0.225    153:06.4
# 98100 98101  0.224    153:08.2
# 98120 98121  0.224    153:10.0
# 98140 98141  0.224    153:11.8
# 98160 98161  0.224    153:13.6
# 98180 98181  0.224463 153:15.4
# 98200 98201  0.224    153:17.2
# 98220 98221  0.224    153:19.0
# 98240 98241  0.224448 153:21.2
# 98260 98261  0.224    153:23.3
# 98280 98281  0.224    153:25.3
# 98300 98301  0.224    153:27.1
# 98320 98321  0.224    153:28.9
# 98340 98341  0.224    153:30.8
# 98360 98361  0.224    153:32.7
# 98380 98381  0.224    153:34.5
# 98400 98401  0.224    153:36.3
# 98420 98421  0.224    153:38.1
# 98440 98441  0.224    153:39.9
# 98460 98461  0.224    153:41.8
# 98480 98481  0.224    153:43.6
# 98500 98501  0.224    153:45.5
# 98520 98521  0.224    153:47.3
# 98540 98541  0.224    153:49.1
# 98560 98561  0.224    153:51.5
# 98580 98581  0.224    153:53.3
# 98600 98601  0.224    153:55.1
# 98620 98621  0.224    153:56.9
# 98640 98641  0.224    153:58.7
# 98660 98661  0.224    154:00.6
# 98680 98681  0.224    154:02.4
# 98700 98701  0.224    154:04.9
# 98720 98721  0.224    154:06.7
# 98740 98741  0.224    154:08.5
# 98760 98761  0.224    154:10.4
# 98780 98781  0.224    154:12.2
# 98800 98801  0.224    154:14.1
# 98820 98821  0.224    154:15.9
# 98840 98841  0.224    154:17.7
# 98860 98861  0.224497 154:19.7
# 98880 98881  0.224482 154:21.4
# 98900 98901  0.224    154:23.3
# 98920 98921  0.225    154:25.2
# 98940 98941  0.225    154:27.1
# 98960 98961  0.225    154:28.9
# 98980 98981  0.224    154:30.8
# 99000 99001  0.224    154:32.6
# 99020 99021  0.224    154:34.5
# 99040 99041  0.224    154:36.4
# 99060 99061  0.224    154:38.8
# 99080 99081  0.224    154:40.7
# 99100 99101  0.224    154:42.6
# 99120 99121  0.224    154:44.4
# 99140 99141  0.224    154:46.2
# 99160 99161  0.224    154:48.1
# 99180 99181  0.224    154:50.0
# 99200 99201  0.224    154:51.8
# 99220 99221  0.224    154:53.7
# 99240 99241  0.224    154:55.5
# 99260 99261  0.224    154:57.3
# 99280 99281  0.224    154:59.5
# 99300 99301  0.224    155:01.4
# 99320 99321  0.224    155:03.2
# 99340 99341  0.224    155:05.0
# 99360 99361  0.224    155:06.8
# 99380 99381  0.224    155:08.7
# 99400 99401  0.224    155:10.5
# 99420 99421  0.224    155:12.3
# 99440 99441  0.224    155:14.2
# 99460 99461  0.224    155:16.0
# 99480 99481  0.224    155:17.9
# 99500 99501  0.224    155:19.7
# 99520 99521  0.224    155:21.5
# 99540 99541  0.2244   155:23.4
# 99560 99561  0.224    155:25.2
# 99580 99581  0.224    155:27.1
# 99600 99601  0.224    155:28.9
# 99620 99621  0.224    155:30.8
# 99640 99641  0.224    155:32.6
# 99660 99661  0.224    155:34.5
# 99680 99681  0.224    155:36.5
# 99700 99701  0.224    155:38.3
# 99720 99721  0.224    155:40.2
# 99740 99741  0.224    155:42.0
# 99760 99761  0.224    155:43.9
# 99780 99781  0.224    155:45.7
# 99800 99801  0.224    155:47.5
# 99820 99821  0.224    155:49.3
# 99840 99841  0.224    155:51.1
# 99860 99861  0.224472 155:53.0
# 99880 99881  0.224    155:54.8
# 99900 99901  0.224    155:56.6
# 99920 99921  0.225    155:58.4
# 99940 99941  0.225    156:00.2
# 99960 99961  0.225    156:02.0
# 99980 99981  0.225    156:03.9
# 100000 100000  0.22458  156:06.1
# Halting: Maximum number of iterations (100000) reached.

# %% [markdown]
# If we haven't quite reached the limit, save the chains here.

# %%
# mcmc.set_max_iterations(5020)
# chains = mcmc.run()
# chains = mcmc.chains()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[34], line 2
#       1 mcmc.set_max_iterations(5020)
# ----> 2 chains = mcmc.run()
#       3 # chains = mcmc.chains()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pints\_mcmc\__init__.py:550, in MCMCController.run(self)
#     548 # Can only run once for each controller instance
#     549 if self._has_run:
# --> 550     raise RuntimeError("Controller is valid for single use only")
#     551 self._has_run = True
#     553 # Check stopping criteria
#
# RuntimeError: Controller is valid for single use only

# %% [markdown]
# ### Saving chains

# %%
import pandas as pd

# %%
# all_param_names = param_names + ["sigma_V", "sigma_c"]
all_param_names = param_names + ["sigma_V"]

# %%
for i, chain in enumerate(chains):
    df = pd.DataFrame(chain, columns=all_param_names)
    df.to_csv(f"chain_data/all_params_tol/chain_{i}.csv")

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Recovering chains from .csv files

# %%
num_chains = 1
list_of_chains = []
for i in range(num_chains):
    df = pd.read_csv(f"chain_data/all_params_tol/chain_{i}.csv", index_col=0)
    chain = df.to_numpy()
    list_of_chains.append(chain)
chains = np.array(list_of_chains)

# %% [markdown]
# ### Trace plots

# %%
import setuptools

# %%
import pints.plot
pints.plot.trace(chains, parameter_names=all_param_names)
plt.show()

# %% [markdown]
# ### Diagnosing using $\hat{R}$

# %% [markdown]
# Here we find the $\hat{R}$ measure for the inference for all different parameters. For well mixed and stationary chains, $\hat{R}$ is close to $1$.

# %%
r_hat_values = pints.rhat(chains, warm_up=0.9)
for i in range(len(all_param_names)):
    print(f"R_hat value for {all_param_names[i]}: {round(r_hat_values[i], 5)}")
output_param_df["R hat"] = r_hat_values[:-1]
# Out:
# R_hat value for g_Na: 1.00075
# R_hat value for g_NaC: 1.00283
# R_hat value for g_K1: 1.01806
# R_hat value for g_K2: 1.00113
# R_hat value for g_x: 1.01065
# R_hat value for g_Ca: 1.00043
# R_hat value for V_Na: 1.00187
# R_hat value for V_K1: 1.00001
# R_hat value for V_K2: 1.01851
# R_hat value for V_K3: 1.00006
# R_hat value for V_x1: 1.00586
# R_hat value for V_x2: 0.99993
# R_hat value for V_Ca: 1.01641
# R_hat value for sigma_V: 1.00866

# %% [markdown]
# Next, calculate the effective sample size, a measure of how many truly independent samples the MCMC algorithm has produced.

# %%
for j, chain in enumerate(chains):
    ess = pints.effective_sample_size(chain)
    for i in range(len(all_param_names)):
        print(f"Effective sample size for chain {j}, param {all_param_names[i]} = {round(ess[i], 5)}")
output_param_df["Effective Sample Size"] = ess[:-1]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 2
#       1 for j, chain in enumerate(chains):
# ----> 2     ess = pints.effective_sample_size(chain)
#       3     for i in range(len(all_param_names)):
#       4         print(f"Effective sample size for chain {j}, param {all_param_names[i]} = {round(ess[i], 5)}")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pints\_diagnostics.py:64, in effective_sample_size(samples)
#      61 if n_samples < 2:
#      62     raise ValueError('At least two samples must be given.')
# ---> 64 return [effective_sample_size_single_parameter(samples[:, i])
#      65         for i in range(0, n_params)]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pints\_diagnostics.py:41, in effective_sample_size_single_parameter(x)
#      32 def effective_sample_size_single_parameter(x):
#      33     """
#      34     Calculates effective sample size (ESS) for samples of a single parameter.
#      35
#    (...)
#      39         A sequence (e.g. a list or a 1-dimensional array) of parameter values.
#      40     """
# ---> 41     rho = autocorrelation(x)
#      42     T = _autocorrelate_negative(rho)
#      43     n = len(x)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pints\_diagnostics.py:17, in autocorrelation(x)
#      12 """
#      13 Calculates autocorrelation for a vector ``x`` using a spectrum density
#      14 calculation.
#      15 """
#      16 x = (x - np.mean(x)) / (np.std(x) * np.sqrt(len(x)))
# ---> 17 result = np.correlate(x, x, mode='full')
#      18 return result[int(result.size / 2):]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\numeric.py:731, in correlate(a, v, mode)
#     660 @array_function_dispatch(_correlate_dispatcher)
#     661 def correlate(a, v, mode='valid'):
#     662     r"""
#     663     Cross-correlation of two 1-dimensional sequences.
#     664
#    (...)
#     729
#     730     """
# --> 731     return multiarray.correlate2(a, v, mode)
#
# KeyboardInterrupt:

# %% [markdown]
# We will now discount the first part of the iterations.

# %%
fraction = 1 / 10
chains = chains[:, -int(fraction * max_iterations):]

# %%
pints.plot.trace(chains, parameter_names=all_param_names)
plt.show()

# %% [markdown]
# ### Predicted time series plots

# %% [markdown]
# #### Chain 1

# %%
pints.plot.series(chains[0, :], problem)
plt.savefig("inference_outputs/series_all_params_tol.png")

# %% [markdown]
# ### Pairwise plots

# %% [markdown]
# Here we will see which parameters are most correlated.

# %%
pints.plot.pairwise(chains[0, :, :-1], parameter_names=all_param_names[:-1])
plt.savefig("inference_outputs/pairwise_all_params_tol.png")

# %% [markdown]
# ## Extracting posterior distributions

# %% [markdown]
# Finally, we will use the stationary chain data to extract posteriors. Assuming chains have converged, we can use their
# iterations as samples from the posterior.

# %%
chains_df = pd.DataFrame(columns=all_param_names + ['chain'])
for i in range(num_chains):
    chain_i_df = pd.DataFrame(chains[i], columns=all_param_names)
    chain_i_df['chain'] = [i] * len(chain_i_df)
    chains_df = pd.concat([chains_df, chain_i_df], ignore_index=True)
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_11892\1106702706.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   chains_df = pd.concat([chains_df, chain_i_df], ignore_index=True)

# %%
means = []
std_devs = []
for name in param_names:
    mean = np.mean(chains_df[name])
    std_dev = np.std(chains_df[name])
    print(f"Mean {name}: {mean}," 
          f" std dev {name}: {std_dev}")
    means.append(mean)
    std_devs.append(std_dev)
output_param_df["Posterior mean"] = means
output_param_df["Posterior std dev"] = std_devs
histograms = chains_df.hist(column=param_names, alpha=0.7)
for i in range(3):
    for j in range(2):
        ax = histograms[i][j]
        ax.axvline(parameters[i * 2 + j], color='r', linestyle='dashed', linewidth=1, label="True")
plt.tight_layout()
plt.legend()
plt.savefig("inference_outputs/posteriors_all_params_tol.png")
# Out:
# Mean g_Na: 3.9004643590853774, std dev g_Na: 0.1284550579389272
# Mean g_NaC: 0.0030218043150433823, std dev g_NaC: 0.00036291092860440174
# Mean g_K1: 1.3936577221725674, std dev g_K1: 0.05626215913788749
# Mean g_K2: 0.06718018658282623, std dev g_K2: 0.002877627767405428
# Mean g_x: 0.7699532649529619, std dev g_x: 0.04220763097546584
# Mean g_Ca: 0.08603544094831114, std dev g_Ca: 0.00453948748957763

# %% [markdown]
# Finally, write all of the parameter data to a final .csv file

# %%
output_param_df.insert(0, "Name", all_param_names[:-1])
output_param_df.to_csv("param_info_tol_all.csv")

# %% [markdown]
# ## Plotting the likelihood surface

# %% [markdown]
# Following [$^{[4]}$](#Sources), we wish to plot the likelihood surface to see if there are any discontinuities. This may imply that the differential
# equation solver is of the incorrect tolerance.

# %%
parameters = [4, 0.003, 1.4, 0.07, 0.8, 0.09, 1.0]
likelihoods = []
g_Na_list = []
for i in range(100):
    g_Na = i / 10
    g_Na_list.append(g_Na)
    parameters[0] = g_Na
    llhd = log_likelihood(np.array(parameters))
    likelihoods.append(llhd)
    print(f"g_Na: {g_Na}, likelihood: {llhd}")
# Out:
# g_Na: 0.0, likelihood: -230825.4279941542
# g_Na: 0.1, likelihood: -227793.23206179112
# g_Na: 0.2, likelihood: -223437.178657597
# g_Na: 0.3, likelihood: -218124.70634077454
# g_Na: 0.4, likelihood: -211696.59772762164
# g_Na: 0.5, likelihood: -203172.07313776435
# g_Na: 0.6, likelihood: -189758.9461445217
# g_Na: 0.7, likelihood: -158273.9285418699
# g_Na: 0.8, likelihood: -16060.204791626156
# g_Na: 0.9, likelihood: -8942.724559160706
# g_Na: 1.0, likelihood: -6122.1619735675995
# g_Na: 1.1, likelihood: -4528.628931141807
# g_Na: 1.2, likelihood: -3504.4196621556916
# g_Na: 1.3, likelihood: -2791.3518198604243
# g_Na: 7.6, likelihood: -282.8229482846262
# g_Na: 7.7, likelihood: -286.23182646966393
# g_Na: 7.8, likelihood: -289.4208651897285
# g_Na: 7.9, likelihood: -292.66499791011006
# g_Na: 8.0, likelihood: -295.77916376570454
# g_Na: 8.1, likelihood: -298.6315574996077
# g_Na: 8.2, likelihood: -301.6851232146812
# g_Na: 8.3, likelihood: -304.4630467041618
# g_Na: 8.4, likelihood: -307.19182168314927
# g_Na: 8.5, likelihood: -309.7376054312257
# g_Na: 8.6, likelihood: -312.15642794273253
# g_Na: 8.7, likelihood: -314.5814064157565
# g_Na: 8.8, likelihood: -317.034067132921
# g_Na: 8.9, likelihood: -319.33490515540865
# g_Na: 9.0, likelihood: -321.4245824361448
# g_Na: 9.1, likelihood: -323.63030394893116
# g_Na: 9.2, likelihood: -325.6245176758718
# g_Na: 9.3, likelihood: -327.6520073951091
# g_Na: 9.4, likelihood: -329.5804352187733
# g_Na: 9.5, likelihood: -331.4346929811144
# g_Na: 9.6, likelihood: -333.1494072114753
# g_Na: 9.7, likelihood: -334.8184029859081
# g_Na: 9.8, likelihood: -336.54107472677964
# g_Na: 9.9, likelihood: -338.0662524470045

# %%
plt.yscale("log")
plt.plot(np.array(g_Na_list), -np.array(likelihoods), "-k")
plt.xlabel("g_Na")
plt.ylabel("likelihood")
plt.title("Likelihood surface varying the g_Na parameter")
# Out:
# Text(0.5, 1.0, 'Likelihood surface varying the g_Na parameter')

# %%
def plot_likelihood(param_index, param_name, upper_bound):
    parameters = [4, 0.003, 1.4, 0.07, 0.8, 0.09, 1.0]
    likelihoods = []
    param_list = []
    for i in range(100):
        param = i / 100 * upper_bound
        param_list.append(param)
        parameters[param_index] = param
        llhd = log_likelihood(np.array(parameters))
        likelihoods.append(llhd)
    plt.yscale("log")
    plt.plot(np.array(param_list), -np.array(likelihoods), "-k")
    plt.xlabel(param_name)
    plt.ylabel("likelihood")
    plt.title(f"Likelihood surface varying the {param_name} parameter")

# %%
plot_likelihood(1, "g_NaC", 0.1)

# %%
plot_likelihood(2, "g_K1", 10)

# %%
plot_likelihood(3, "g_K2", 1)

# %%
plot_likelihood(4, "g_x", 1)

# %%
plot_likelihood(5, "g_Ca", 1)

# %% [markdown]
# ## Sources
# $^{[1]}$ J. Keener and J. Sneyd (1998) - Mathematical Physiology https://link.springer.com/book/10.1007/b98841
#
# $^{[2]}$ G. W. Beeler and H. Reuter, RECONSTRUCTION OF THE ACTION POTENTIAL OF
# VENTRICULAR MYOCARDIAL FIBRES, J. Physiol. **268** (1977), pp. 177-210 https://doi.org/10.1113/jphysiol.1977.sp011853
#
# $^{[3]}$ P. Noble, F. Fenton, cellML - Beeler, Reuter 1997, date accessed: 22/03/24, https://models.cellml.org/e/1
#
# $^{[4]}$ R. Creswell, K. M. Shepherd, B. Lambert, G. R. Mirams, C. L. Lei, S. Tavener, M. Robinson and D. J. Gavaghan, Understanding the impact of numerical solvers on inference for differential equation modelsial, J. R. Soc. Interface **21** (2024) pp. 202303https://pubmed.ncbi.nlm.nih.gov/38442857/dels
